# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.0</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.AzureAI\bin\Debug\net9.0\Microsoft.Agents.AI.AzureAI.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI\bin\Debug\net9.0\Microsoft.Agents.AI.dll"

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = "gpt-4o";

var imgPath ="../../files/home.png";

# %%
const string AgentName = "Vision-Agent";
const string AgentInstructions = "You are my furniture sales consultant, you can find different furniture elements from the pictures and give me a purchase suggestion";

# %%
using System.IO;

async Task<byte[]> OpenImageBytesAsync(string path)
{
	return await File.ReadAllBytesAsync(path);
}

var imageBytes = await OpenImageBytesAsync(imgPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
var agentMetadata = await persistentAgentsClient.Administration.CreateAgentAsync(
    model: azure_foundry_model_id,
    name: AgentName,
    instructions: AgentInstructions);

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentMetadata.Value.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
// Create the chat message with text and image content
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("Can you identify the furniture items in this image and suggest which ones would fit well in a modern living room?"), new DataContent(imageBytes, "image/png")
]);

# %%
Console.WriteLine(await agent.RunAsync(userMessage, thread));
# Out:
# In this image, I can identify the following furniture and decor items:
#
# 1. **TV Stand/Console Table**: A sleek wooden TV stand with drawers and open shelves.
#    - **Suggestion**: This matches well with a modern living room due to its clean lines and functional design. Opt for similar styles in light or neutral wood tones to maintain a streamlined look.
#
# 2. **Wall-Mounted TV**: Space-saving and minimalist.
#
# 3. **Accent Chair**: A deep blue, high-backed chair with modern design, displaying both elegance and comfort.
#    - **Suggestion**: Definitely a great addition to a modern living room. Consider pairing similar chairs with bold fabric colors to add a touch of contrast.
#
# 4. **Coffee Table**: A mid-century modern-style coffee table with rounded edges and wooden legs.
#    - **Suggestion**: Works perfectly for a modern living room due to its simplicity and functionality. Keep an option with a similar light wood tone or marble finish.
#
# 5. **Sofa**: A white modern sofa adorned with blue and neutral-colored throw pillows.
#    - **Suggestion**: This fits wonderfully into a modern living room. Opt for a sleek and clean-lined sofa like this in neutral shades.
#
# 6. **Pendant Floor Lamp**: A slim and stylish lamp with a minimalist stand and globe-like pendants.
#    - **Suggestion**: Ideal for modern spaces. Look for similar geometric lighting designs for sophistication.
#
# 7. **Lighting Fixture**: A large, modern chandelier with black framing and multiple globe bulbs.
#    - **Suggestion**: Bold and elegant, this statement piece will highlight the room's modern feel. Look for similar lighting fixtures with metallic finishes.
#
# 8. **Side Table**: A small, minimalist side table next to the sofa.
#    - **Suggestion**: Complement this modern living room with simple, metal or glass side tables.
#
# 9. **Wall Art**: A framed graphic art with a deer motif.
#    - **Suggestion**: Keep this style of simple, nature-inspired art for a modern twist. Aim for minimalistic frames and abstract designs.
#
# 10. **Curtains**: Gray and white sheer curtains for soft natural lighting.
#    - **Suggestion**: Sheer and textured curtains like these help create a warm and modern ambiance. Stick to neutral tones.
#
# ### Recommended adjustments for a modern living room:
# - Add plants or greenery for a fresh, lively touch.
# - Layer rugs with subtle patterns to soften the wood floor and enhance comfort.
# - Consider incorporating metallic or glass decor accents to match the lighting and overall modern aesthetic.
#
# Would you like me to suggest specific brands or stores?
