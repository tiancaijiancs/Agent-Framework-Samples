# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.2"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.1-preview.1.25474.6"

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
const string AgentName = "Bing-Agent-Framework";
const string AgentInstructions = "You are an AI assistant that helps people find information.";

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
var conn_id = Environment.GetEnvironmentVariable("BING_CONNECTION_ID");

# %%
var bingGroudingConfig = new BingGroundingSearchConfiguration(conn_id);
// bingGroudingConfig.Count =5;
// bingGroudingConfig.Market= "en-US";
// bingGroudingConfig.SetLang= "en";

# %%
BingGroundingToolDefinition bingGroundingTool = new(
    new BingGroundingSearchToolParameters(
        [bingGroudingConfig]
    )
);

# %%
bingGroundingTool
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Azure.AI.Agents.Persistent.BingGroundingToolDefinition</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>BingGrounding</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Azure.AI.Agents.Persistent.BingGroundingSearchToolParameters</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>SearchConfigurations</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Azure.AI.Agents.Persistent.BingGroundingSearchConfiguration</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>ConnectionId</td><td><div class="dni-plaintext"><pre>/subscriptions/ee72069a-4726-4e1a-afe6-7f14e9b9d362/resourceGroups/rg-kinfeylo/providers/Microsoft.CognitiveServices/accounts/kinfeylo-aifoundry-proj-resource/projects/kinfeylo-aifoundry-project/connections/kinfeybingsearch</pre></div></td></tr><tr><td>Market</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>SetLang</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Count</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Freshness</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
PersistentAgent agent =await persistentAgentsClient.Administration.CreateAgentAsync(
    model: azure_foundry_model_id,
    name: "bing-search-agent",
    instructions: "Use the bing grounding tool to answer questions.",
    tools: [bingGroundingTool]
);

# %%
string agentId = agent.Id;

# %%
agentId
# Out:
# asst_hWWVFF0kH5a9GYMyA6cSCwbk

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentId);

# %%
AgentThread thread = agent.GetNewThread();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("Could you please describe the workshop according to the link https://github.com/kinfey/GHCAgentWorkshop?")
]);

# %%
var result = await agent.RunAsync(userMessage, thread);

# %%
result
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>The GitHub Copilot Agent Workshop is designed to introduce participants to the capabilities of GitHub Copilot as an integrated development assistant. In this workshop, you can create Copilot applications without writing any code, empowering individuals to act as project managers with AI&#39;s assistance...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Messages</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>The GitHub Copilot Agent Workshop is designed to introduce participants to the capabilities of GitHub Copilot as an integrated development assistant. In this workshop, you can create Copilot applications without writing any code, empowering individuals to act as project managers with AI&#39;s assistance...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>AuthorName</td><td><div class="dni-plaintext"><pre>asst_hWWVFF0kH5a9GYMyA6cSCwbk</pre></div></td></tr><tr><td>CreatedAt</td><td><span>2025-10-01 15:58:31Z</span></td></tr><tr><td>Role</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>assistant</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Value</td><td><div class="dni-plaintext"><pre>assistant</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Text</td><td><div class="dni-plaintext"><pre>The GitHub Copilot Agent Workshop is designed to introduce participants to the capabilities of GitHub Copilot as an integrated development assistant. In this workshop, you can create Copilot applications without writing any code, empowering individuals to act as project managers with AI&#39;s assistance.
#
# Key components of the workshop include:
# - Understanding the abilities of GitHub Copilot, including context completion and code optimization.
# - Learning about the Agent mode within GitHub Copilot Chat, which simplifies creating project-specific applications.
# - Hands-on experiments like building a stock analysis app, deploying GPT-5 applications, and generating UIs and front-end setups for applications using GitHub Copilot Agent.
#
# Participants need a GitHub account, a Python environment (preferably version 3.10.8+), Visual Studio Code Insider, and relevant Python extensions as prerequisites【3:0†source】.</pre></div></td></tr><tr><td>Contents</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>The GitHub Copilot Agent Workshop is designed to introduce participants to the capabilities of GitHub Copilot as an integrated development assistant. In this workshop, you can create Copilot applications without writing any code, empowering individuals to act as project managers with AI&#39;s assistance...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Text</td><td><div class="dni-plaintext"><pre>The GitHub Copilot Agent Workshop is designed to introduce participants to the capabilities of GitHub Copilot as an integrated development assistant. In this workshop, you can create Copilot applications without writing any code, empowering individuals to act as project managers with AI&#39;s assistance.
#
# Key components of the workshop include:
# - Understanding the abilities of GitHub Copilot, including context completion and code optimization.
# - Learning about the Agent mode within GitHub Copilot Chat, which simplifies creating project-specific applications.
# - Hands-on experiments like building a stock analysis app, deploying GPT-5 applications, and generating UIs and front-end setups for applications using GitHub Copilot Agent.
#
# Participants need a GitHub account, a Python environment (preferably version 3.10.8+), Visual Studio Code Insider, and relevant Python extensions as prerequisites【3:0†source】.</pre></div></td></tr><tr><td>Annotations</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>RawRepresentation</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>AdditionalProperties</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>MessageId</td><td><div class="dni-plaintext"><pre>run_7osg91SivI7ESIq6S9XZ932T</pre></div></td></tr><tr><td>RawRepresentation</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>AdditionalProperties</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Text</td><td><div class="dni-plaintext"><pre>The GitHub Copilot Agent Workshop is designed to introduce participants to the capabilities of GitHub Copilot as an integrated development assistant. In this workshop, you can create Copilot applications without writing any code, empowering individuals to act as project managers with AI&#39;s assistance.
#
# Key components of the workshop include:
# - Understanding the abilities of GitHub Copilot, including context completion and code optimization.
# - Learning about the Agent mode within GitHub Copilot Chat, which simplifies creating project-specific applications.
# - Hands-on experiments like building a stock analysis app, deploying GPT-5 applications, and generating UIs and front-end setups for applications using GitHub Copilot Agent.
#
# Participants need a GitHub account, a Python environment (preferably version 3.10.8+), Visual Studio Code Insider, and relevant Python extensions as prerequisites【3:0†source】.</pre></div></td></tr><tr><td>UserInputRequests</td><td><i>(empty)</i></td></tr><tr><td>AgentId</td><td><div class="dni-plaintext"><pre>asst_hWWVFF0kH5a9GYMyA6cSCwbk</pre></div></td></tr><tr><td>ResponseId</td><td><div class="dni-plaintext"><pre>run_7osg91SivI7ESIq6S9XZ932T</pre></div></td></tr><tr><td>CreatedAt</td><td><span>2025-10-01 15:58:31Z</span></td></tr><tr><td>Usage</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.Extensions.AI.UsageDetails</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>InputTokenCount</td><td><div class="dni-plaintext"><pre>3632</pre></div></td></tr><tr><td>OutputTokenCount</td><td><div class="dni-plaintext"><pre>196</pre></div></td></tr><tr><td>TotalTokenCount</td><td><div class="dni-plaintext"><pre>3828</pre></div></td></tr><tr><td>AdditionalCounts</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>RawRepresentation</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>The GitHub Copilot Agent Workshop is designed to introduce participants to the capabilities of GitHub Copilot as an integrated development assistant. In this workshop, you can create Copilot applications without writing any code, empowering individuals to act as project managers with AI&#39;s assistance...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Messages</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>The GitHub Copilot Agent Workshop is designed to introduce participants to the capabilities of GitHub Copilot as an integrated development assistant. In this workshop, you can create Copilot applications without writing any code, empowering individuals to act as project managers with AI&#39;s assistance...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>AuthorName</td><td><div class="dni-plaintext"><pre>asst_hWWVFF0kH5a9GYMyA6cSCwbk</pre></div></td></tr><tr><td>CreatedAt</td><td><span>2025-10-01 15:58:31Z</span></td></tr><tr><td>Role</td><td><details class="dni-treeview"
