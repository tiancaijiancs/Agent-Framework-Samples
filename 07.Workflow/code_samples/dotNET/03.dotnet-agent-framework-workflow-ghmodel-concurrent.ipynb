# %% [markdown]
# # ⚡ Concurrent Agent Workflows with GitHub Models (.NET)
#
# ## 📋 High-Performance Parallel Processing Tutorial
#
# This notebook demonstrates **concurrent workflow patterns** using the Microsoft Agent Framework for .NET and GitHub Models. You'll learn how to build high-performance, parallel processing workflows that maximize throughput by executing multiple AI agents simultaneously while maintaining coordination and data consistency.
#
# ## 🎯 Learning Objectives
#
# ### 🚀 **Concurrent Processing Fundamentals**
# - **Parallel Agent Execution**: Run multiple AI agents simultaneously for maximum performance
# - **Async/Await Patterns**: Leverage .NET's async programming model for efficient concurrency
# - **GitHub Models Integration**: Coordinate multiple concurrent calls to GitHub's AI model inference service
# - **Resource Management**: Efficiently manage AI model resources across concurrent operations
#
# ### 🏗️ **Advanced Concurrency Architecture**
# - **Task-Based Parallelism**: Use .NET Task Parallel Library for optimal concurrent execution
# - **Synchronization Patterns**: Coordinate concurrent agents while avoiding race conditions
# - **Load Balancing**: Distribute work efficiently across available concurrent processing capacity
# - **Fault Tolerance**: Handle individual agent failures without stopping the entire workflow
#
# ### 🏢 **Enterprise Concurrent Applications**
# - **High-Volume Document Processing**: Process multiple documents simultaneously
# - **Real-Time Content Analysis**: Concurrent analysis of incoming data streams
# - **Batch Processing Optimization**: Maximize throughput for large-scale data processing operations
# - **Multi-Modal Analysis**: Parallel processing of different content types and formats
#
# ## ⚙️ Prerequisites & Setup
#
# ### 📦 **Required NuGet Packages**
#
# Essential packages for high-performance concurrent workflows:
#
# ```xml
# <!-- Core AI Framework with Async Support -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
#
# <!-- Client Model Abstractions for API Communication -->
# <PackageReference Include="System.ClientModel" Version="1.6.1.0" />
#
# <!-- Azure Identity and Async LINQ for Advanced Operations -->
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
#
# <!-- Local Agent Framework References -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions with async support -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - GitHub Models integration with concurrency -->
# ```
#
# ### 🔑 **GitHub Models Configuration**
#
# **Environment Setup (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Concurrent Processing Considerations:**
# ```csharp
# // Configure for concurrent operations
# var clientOptions = new OpenAIClientOptions()
# {
#     Endpoint = new Uri(githubEndpoint),
#     // Configure connection pooling for concurrent requests
#     NetworkTimeout = TimeSpan.FromMinutes(5)
# };
# ```
#
# ### 🏗️ **Concurrent Workflow Architecture**
#
# ```mermaid
# graph TD
#     A[Workflow Input] --> B[Task Distribution]
#     B --> C[Concurrent Agent Pool]
#     C --> D[Agent Task 1]
#     C --> E[Agent Task 2]
#     C --> F[Agent Task 3]
#     C --> G[Agent Task N]
#
#     D --> H[Result Aggregation]
#     E --> H
#     F --> H
#     G --> H
#
#     H --> I[Synchronized Output]
#
#     J[GitHub Models API] --> D
#     J --> E
#     J --> F
#     J --> G
#
#     K[.NET Task Scheduler] --> C
# ```
#
# **Key Components:**
# - **Task Parallel Library**: .NET's built-in support for concurrent operations
# - **Agent Pool**: Multiple agent instances for parallel processing
# - **Result Aggregation**: Coordination and merging of concurrent agent results
# - **Synchronization Points**: Ensure data consistency across concurrent operations
#
# ## 🎨 **Concurrent Workflow Design Patterns**
#
# ### 🔍 **Parallel Research & Analysis**
# ```
# Research Topic → Concurrent Research Agents → Result Synthesis → Final Report
# ```
#
# ### 📊 **Multi-Source Data Processing**
# ```
# Data Sources → Parallel Processing Agents → Data Integration → Unified Output
# ```
#
# ### 🎭 **Content Generation Pipeline**
# ```
# Content Requirements → Concurrent Content Generators → Quality Review → Final Content
# ```
#
# ### 🔄 **Fan-Out/Fan-In Processing**
# ```
# Single Input → Multiple Concurrent Processors → Result Aggregation → Single Output
# ```
#
# ## 🏢 **Enterprise Performance Benefits**
#
# ### ⚡ **Throughput & Scalability**
# - **Linear Performance Scaling**: Add more concurrent agents to increase throughput
# - **Resource Utilization**: Maximum efficiency of available AI model capacity
# - **Reduced Processing Time**: Significant time reduction through parallel execution
# - **Elastic Scaling**: Dynamically adjust concurrent agent count based on workload
#
# ### 🛡️ **Reliability & Resilience**
# - **Fault Isolation**: Individual agent failures don't affect other concurrent operations
# - **Graceful Degradation**: System continues operating with reduced agent capacity
# - **Error Recovery**: Automatic retry mechanisms for failed concurrent operations
# - **Load Distribution**: Even distribution of work across available agents
#
# ### 📊 **Performance Monitoring**
# - **Concurrent Execution Metrics**: Track performance of all parallel operations
# - **Resource Usage Analytics**: Monitor CPU, memory, and network utilization
# - **Throughput Analysis**: Measure efficiency gains from concurrent processing
# - **Bottleneck Detection**: Identify and resolve performance constraints
#
# ### 🔧 **Development & Operations**
# - **Async Programming Model**: Leverage .NET's mature async/await patterns
# - **Task Coordination**: Built-in task management and coordination capabilities
# - **Exception Handling**: Comprehensive error handling for concurrent operations
# - **Debugging Support**: Visual Studio debugging tools for concurrent workflows
#
# Let's build high-performance concurrent AI workflows with .NET! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.0</span></li></ul></div></div>

# %%
#r "nuget: System.ClientModel, 1.6.1.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>System.ClientModel, 1.6.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.15.0</span></li><li><span>OpenTelemetry.Api, 1.0.1</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.Workflows\bin\Debug\net9.0\Microsoft.Agents.AI.Workflows.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.OpenAI\bin\Debug\net9.0\Microsoft.Agents.AI.OpenAI.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI\bin\Debug\net9.0\Microsoft.Agents.AI.dll"

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4</span></li></ul></div></div>

# %%
using System;
using System.ComponentModel;
using System.ClientModel;
using OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;
using Microsoft.Agents.AI.Workflows.Reflection;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var github_endpoint = Environment.GetEnvironmentVariable("GITHUB_ENDPOINT") ?? throw new InvalidOperationException("GITHUB_ENDPOINT is not set.");
var github_model_id =  "gpt-4o";
var github_token = Environment.GetEnvironmentVariable("GITHUB_TOKEN") ?? throw new InvalidOperationException("GITHUB_TOKEN is not set.");

# %%
var openAIOptions = new OpenAIClientOptions()
{
    Endpoint = new Uri(github_endpoint)
};

# %%
var openAIClient = new OpenAIClient(new ApiKeyCredential(github_token), openAIOptions);

# %%
const string ResearcherAgentName = "Researcher-Agent";
const string ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction.";

# %%
const string PlanAgentName = "Plan-Agent";
const string PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings.";

# %%
AIAgent researcherAgent = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:ResearcherAgentName,instructions:ResearcherAgentInstructions);
AIAgent plannerAgent  = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:PlanAgentName,instructions:PlanAgentInstructions);

# %%
public class ConcurrentStartExecutor() :
    ReflectingExecutor<ConcurrentStartExecutor>("ConcurrentStartExecutor"),
    IMessageHandler<string>
{
    /// <summary>
    /// Starts the concurrent processing by sending messages to the agents.
    /// </summary>
    /// <param name="message">The user message to process</param>
    /// <param name="context">Workflow context for accessing workflow services and adding events</param>
    /// <returns>A task representing the asynchronous operation</returns>
    public async ValueTask HandleAsync(string message, IWorkflowContext context)
    {
        // Broadcast the message to all connected agents. Receiving agents will queue
        // the message but will not start processing until they receive a turn token.
        await context.SendMessageAsync(new ChatMessage(ChatRole.User, message));
        // Broadcast the turn token to kick off the agents.
        await context.SendMessageAsync(new TurnToken(emitEvents: true));
    }
}

/// <summary>
/// Executor that aggregates the results from the concurrent agents.
/// </summary>
public class ConcurrentAggregationExecutor() :
    ReflectingExecutor<ConcurrentAggregationExecutor>("ConcurrentAggregationExecutor"),
    IMessageHandler<ChatMessage>
{
    private readonly List<ChatMessage> _messages = [];

    /// <summary>
    /// Handles incoming messages from the agents and aggregates their responses.
    /// </summary>
    /// <param name="message">The message from the agent</param>
    /// <param name="context">Workflow context for accessing workflow services and adding events</param>
    /// <returns>A task representing the asynchronous operation</returns>
    public async ValueTask HandleAsync(ChatMessage message, IWorkflowContext context)
    {
        this._messages.Add(message);

        if (this._messages.Count == 2)
        {
            var formattedMessages = string.Join(Environment.NewLine, this._messages.Select(m => $"{m.AuthorName}: {m.Text}"));
            await context.YieldOutputAsync(formattedMessages);
        }
    }
}

# %%
var startExecutor = new ConcurrentStartExecutor();
var aggregationExecutor = new ConcurrentAggregationExecutor();

# %%
var workflow = new WorkflowBuilder(startExecutor)
            .AddFanOutEdge(startExecutor, targets: [researcherAgent, plannerAgent])
            .AddFanInEdge(aggregationExecutor, sources: [researcherAgent, plannerAgent])
            .WithOutputFrom(aggregationExecutor)
            .Build();

# %%
        StreamingRun run = await InProcessExecution.StreamAsync(workflow, "Plan a trip to Seattle in December");
        await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
        {
            if (evt is WorkflowOutputEvent output)
            {
                Console.WriteLine($"Workflow completed with results:\n{output.Data}");
            }
        }
# Out:
# Workflow completed with results:
# Plan-Agent: Seattle in December is a magical destination with festive lights, cozy coffeehouses, holiday events, and a chill atmosphere. Here’s a detailed travel plan to enjoy your trip:
#
# ---
#
# ### **Length of Stay:** 4 days, 3 nights
# (You can extend depending on your preferences.)
#
# ---
#
# ### **Weather Overview**
# - Temperatures: Avg. highs 45°F (7°C), avg. lows 36°F (2°C).
# - Expect rain, so pack waterproof gear like raincoats, boots, and umbrellas. Bring warm clothing like sweaters, jackets, scarves, and gloves.
#
# ---
#
# ### **Day-by-Day Itinerary**
#
# ---
#
# #### **Day 1: Downtown Seattle & Iconic Landmarks**
# **Morning:**
# 1. **Arrival & Check-In:**
#    - Stay in downtown Seattle for convenient access to attractions. Options include The Westin Seattle or boutique hotels like Hotel Theodore.
#
# 2. **Breakfast:**
#    - Visit *Tilikum Place Café* or *The 5 Point Café* for hearty Seattle-style breakfast with fresh ingredients.
#
# 3. **Pike Place Market:**
#    - Start your day at the historic Pike Place Market. Watch the fishmongers toss fish, explore artisan stalls, and check out *Beecher’s Handmade Cheese* for samples.
#
# ---
#
# **Afternoon:**
# 1. **Waterfront Attractions:**
#    - Walk to the nearby Seattle Waterfront. Visit the *Seattle Aquarium* or stroll around the piers for views of Puget Sound.
#    - Lunch at *Elliott’s Oyster House*, known for seafood like salmon and shellfish.
#
# 2. **The Gum Wall:**
#    - Stop by this quirky wall covered in colorful gum.
#
# 3. **Ride the Seattle Great Wheel:**
#    - Enjoy panoramic views of Elliott Bay from this giant Ferris wheel.
#
# ---
#
# **Evening:**
# 1. **Dinner:**
#    - Head to *Canlis* for a scenic, fine-dining experience overlooking Lake Union.
#
# 2. **Holiday Lights:**
#    - Explore holiday light displays around the Westlake Center and enjoy ice skating at the seasonal rink (if available).
#
# ---
#
# #### **Day 2: Arts, Culture & Cozy Spots**
# **Morning:**
# 1. **Breakfast:**
#    - Fuel up at *Storyville Coffee* in Pike Place Market for stunning views and comforting coffee.
#
# 2. **Museum Day:**
#    - Immerse yourself in Seattle’s arts and science scene.
#      - Visit the *Museum of Pop Culture (MoPOP)* to explore exhibits on music, film, and sci-fi.
#      - Head to *Chihuly Garden and Glass* for breathtaking glass art installations.
#
# ---
#
# **Afternoon:**
# 1. **Seattle Center:**
#    - Explore the grounds of Seattle Center and take an elevator ride up the *Space Needle*. Admire the city’s wintry skyline.
#
# 2. **Lunch at Taylor Shellfish Farms:**
#    - Enjoy fresh oysters and hearty seafood bowls.
#
# 3. **Pacific Science Center:**
#    - Families could enjoy educational exhibits and IMAX screenings here.
#
# ---
#
# **Evening:**
# 1. **Dinner:**
#    - Try cozy Italian fare at *The Pink Door*, known for its festive ambiance.
#
# 2. **Live Jazz:**
#    - Visit *The Royal Room* or *Tula’s Jazz Club* for a relaxed night with great music.
#
# ---
#
# #### **Day 3: Daytrip or Local Exploration**
# **Option 1: Daytrip to Snoqualmie Falls**
# - Rent a car and drive 45 minutes to see Snoqualmie Falls. December snow might add extra beauty to the falls. Stop by the *Salish Lodge* for breakfast or lunch overlooking the falls.
#
# **Option 2: Explore Local Neighborhoods**
# **Morning:**
# 1. **Capitol Hill:**
#    - Enjoy brunch at *Witness Bar* or *Oddfellows Cafe*. Explore indie shops, bookstores, and unique boutiques.
#
# **Afternoon:**
# 1. **Ballard Locks:**
#    - Visit the Ballard Locks and fish ladder, even if quieter this time of year.
#
# **Evening:**
# 1. **Fremont Nightlife:**
#    - Check out quirky bars and restaurants around Fremont, known for its unique art pieces like the Fremont Troll.
#    - Dinner at *Revel*, a modern Korean fusion spot.
#
# ---
#
# #### **Day 4: Relax & Departure**
# **Morning:**
# 1. **Coffee Crawl:**
#    - Before leaving, grab a top-notch coffee at Seattle gems like *Victrola Coffee Roasters*, *Vivace*, or *Elm Coffee Roasters*.
#
# 2. **Shopping & Souvenirs:**
#    - Stroll through Pike Place Market one last time to pick up local items or visit the *Seattle Made* store.
#
# 3. **Departure:**
#    - Head to Seattle-Tacoma International Airport (SEA) to catch your flight out.
#
# ---
#
# ### **General Tips:**
# - **Transportation:** Use the Link Light Rail for quick, affordable transit around Seattle’s core.
# - **Packing Essentials:** Waterproof layers, sturdy walking shoes, a camera, and warm accessories.
# - **Holiday Events:** Research Seattle’s December activities beforehand, like holiday concerts, crafts fairs, and the Christmas Ship Festival.
#
# Researcher-Agent: Seattle in December offers a mix of festive holiday vibes, cozy indoor attractions, and the chance to explore iconic landmarks amidst the Pacific Northwest's cool, rainy winter season. Here’s a detailed travel plan for your Seattle trip in December, including attractions and tips for making the most of your visit.
#
# ---
#
# ## **Top Attractions in Seattle for December**
#
# ### 1. **The Space Needle**
#    - **Why Visit**: Panoramic views of Seattle and beyond, including Mount Rainier (on a clear day), Puget Sound, and the city skyline.
#    - **Tips**: Winter skies can be cloudy, so check the weather forecast for visibility and consider visiting at sunset for stunning views of the city lights.
#    - **Duration**: 1–2 hours.
#
# ### 2. **Chihuly Garden and Glass**
#    - **Why Visit**: Stunning glass art installations by Dale Chihuly that look even more magical in the moody, wintertime light.
#    - **Tips**: Save time and money by purchasing a joint ticket with the Space Needle as they are in the same area (Seattle Center).
#    - **Duration**: 1 hour.
#
# ### 3. **Pike Place Market**
#    - **Why Visit**: One of Seattle’s most iconic attractions, bustling with fresh seafood, artisan goods, and local produce. Don’t miss the famous fish-throwing vendors and the quirky shops.
#    - **December Vibes**: The market is decorated with festive lights and Christmas-themed stalls in December.
#    - **Must-Try Food Stops**:
#        - Beecher’s Handmade Cheese for mac and cheese.
#        - Piroshky Piroshky for fresh pastries.
#        - The first Starbucks store for memorabilia and coffee.
#    - **Duration**: 2–3 hours.
#
# ### 4. **Museum of Pop Culture (MoPOP)**
#    - **Why Visit**: A unique museum covering music, sci-fi, video games, and pop culture. It's engaging for both adults and kids.
#    - **Exhibits to Watch For**: Jimi Hendrix exhibit, Science Fiction and Fantasy Hall of Fame, and rotating exhibitions like costume design or famous movie props.
#    - **Duration**: 2–3 hours.
#
# ### 5. **Seattle Aquarium**
#    - **Why Visit**: Experience marine life unique to the Pacific Northwest, plus family-friendly exhibits.
#    - **December Bonus**: Indoors and cozy, perfect for a rainy day.
#    - **Duration**: 1.5–2 hours.
#
# ### 6. **Holiday Events and Attractions**
#    - **Why Visit**: December brings holiday-themed activities to Seattle:
#      - **Enchant Christmas**: A massive light maze and market at T-Mobile Park, featuring millions of lights and ice skating.
#      - **Christmas Ship Festival**: Evening boat tours where ships decorated with lights sail around Puget Sound while carolers sing onboard.
#      - **Snowflake Lane in Bellevue**: A nightly parade with lights, music, and snow in nearby Bellevue, about 20 mins from Seattle.
#
# ### 7. **Kerry Park**
#    - **Why Visit**: Best-known viewpoint of Seattle's skyline, particularly stunning at night during December with holiday lights dotting the city.
#    - **Duration**: 20–30 minutes.
#
# ### 8. **Underground Tour in Pioneer Square**
#    - **Why Visit**: A quirky, informative tour of Seattle’s underground passageways and the history of the city’s reconstruction after the Great Fire of 1889.
#    - **Duration**: 1.5 hours.
#
# ### 9. **Discovery Park**
#    - **Why Visit**: Quiet and serene in the winter, this 534-acre park offers trails, beach views, and chances to spot wildlife.
#    - **Tips**: Wear layers and waterproof gear since the weather can be wet and chilly.
#
# ### 10. **Winter Hikes or Day Trips**
#    - **Options**:
#      - **Snoqualmie Falls**: Just 40 minutes from Seattle, this 268-foot waterfall is particularly dramatic in the winter.
#      - **Leavenworth**: A Bavarian-style village that transforms into a glittering Christmas wonderland in December. About 2.5 hours from Seattle.
#      - **Mount Rainier National Park**: Only 1.5–2 hours away, ideal for snowshoeing, sledding, or simply enjoying the snowy mountain landscapes.
#
# ---
#
# ## **Detailed 4-Day Plan**
#
# ### **Day 1: Exploring Downtown Essentials**
# - Morning:
#   - Start your day at *Pike Place Market*: Explore the shops, grab breakfast (don’t miss the pastries at Piroshky Piroshky), and watch the iconic fishmongers throw fish.
# - Afternoon:
#   - Walk down to the *Seattle Waterfront* for lunch at a seafood restaurant. Visit the *Seattle Aquarium* afterward.
#   - Take a ride on the *Seattle Great Wheel* for waterfront views.
# - Evening:
#   - Head to *Pioneer Square* for dinner and attend the *Underground Tour*.
#   - Stroll around to see any holiday lights and decorations.
#
# ### **Day 2: Seattle Center & Iconic Landmarks**
# - Morning:
#   - Begin with the *Space Needle*. Plan your visit early to avoid crowds and get great daylight views.
#   - Follow it up with *Chihuly Garden and Glass* (joint ticket option).
# - Afternoon:
#   - Visit *Museum of Pop Culture (MoPOP)*. Be sure to check out rotating exhibits!
# - Evening:
#   - End the day with dinner at a nearby restaurant. Optionally, visit *Enchant Christmas* or head to *Kerry Park* for city views.
#
# ### **Day 3: Outdoor Adventures & Holiday Fun**
# - Morning:
#   - Take a day trip to *Snoqualmie Falls*. Stop by Salish Lodge for breakfast or coffee with views of the falls.
# - Afternoon:
#   - Return to Seattle and spend time in *Discovery Park*, exploring trails and shoreline views.
# - Evening:
#   - Attend the *Christmas Ship Festival* or visit *Snowflake Lane* in Bellevue for festive fun and performances.
#
# ### **Day 4: Optional Day Trips or Wrap-up**
# - Option 1: Drive to *Leavenworth* for a full day of holiday festivities and twinkling lights.
# - Option 2: Head to *Mount Rainier National Park* for snow-covered adventures like sledding, tubing, or snowshoeing.
# - Option 3: Spend the day shopping and dining in Seattle. You can check out the *Seattle Art Museum (SAM)* or take a brewery tour at one of the many local breweries.
#
# ---
#
# ## **Tips for Visiting Seattle in December**
# 1. **Weather**: December is rainy and chilly, with temperatures averaging between 37°F and 48°F. Bring waterproof shoes, a warm coat, and a good umbrella!
# 2. **Getting Around**: Invest in an ORCA card for public transportation. Ride the Link Light Rail to save time and avoid parking fees downtown.
# 3. **Festive Attire**: If attending holiday-themed events, consider bringing cozy holiday hats or festive wear to embrace the spirit.
# 4. **Rain Plan**: Keep flexibility in your schedule and prioritize indoor attractions on rainy days.
#
# ---
#
# Enjoy your trip to Seattle! From holiday sparkle to classic landmarks, December is a magical time to experience the Emerald City.
