# %% [markdown]
# # ⚡ Concurrent Agent Workflows with GitHub Models (Python)
#
# ## 📋 Advanced Parallel Processing Tutorial
#
# This notebook demonstrates **concurrent workflow patterns** using the Microsoft Agent Framework. You'll learn how to build high-performance, parallel processing workflows where multiple AI agents execute simultaneously, dramatically improving throughput and enabling sophisticated multi-threaded business processes.
#
# ## 🎯 Learning Objectives
#
# ### 🚀 **Concurrent Processing Fundamentals**
# - **Parallel Agent Execution**: Run multiple agents simultaneously for maximum efficiency
# - **Workflow Orchestration**: Coordinate concurrent operations while maintaining data consistency
# - **Performance Optimization**: Achieve significant speedup through parallel processing
# - **Resource Management**: Efficiently utilize AI model resources across concurrent operations
#
# ### 🏗️ **Advanced Concurrency Patterns**
# - **Fork-Join Processing**: Split work across multiple agents and merge results
# - **Pipeline Parallelism**: Overlapping execution stages for continuous throughput
# - **Load Balancing**: Distribute work evenly across available agent resources
# - **Synchronization Points**: Coordinate concurrent agents at critical workflow stages
#
# ### 🏢 **Enterprise Concurrent Applications**
# - **High-Volume Document Processing**: Process multiple documents simultaneously
# - **Real-Time Content Analysis**: Concurrent analysis of incoming data streams
# - **Batch Processing Optimization**: Maximize throughput for large-scale operations
# - **Multi-Modal Analysis**: Parallel processing of different content types (text, images, data)
#
# ## ⚙️ Prerequisites & Setup
#
# ### 📦 **Required Dependencies**
#
# Install Agent Framework with concurrent workflow capabilities:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub Models Configuration**
#
# **Environment Setup (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Concurrent Processing Considerations:**
# - **Rate Limits**: Monitor GitHub Models API rate limits for concurrent requests
# - **Resource Usage**: Consider memory and CPU usage with multiple concurrent agents
# - **Error Handling**: Implement robust error recovery for parallel operations
#
# ### 🏗️ **Concurrent Workflow Architecture**
#
# ```mermaid
# graph TD
#     A[Workflow Start] --> B[Concurrent Execution]
#     B --> C[Agent Pool 1]
#     B --> D[Agent Pool 2]
#     B --> E[Agent Pool 3]
#     C --> F[Result Aggregation]
#     D --> F
#     E --> F
#     F --> G[Final Output]
#
#     H[GitHub Models API] --> C
#     H --> D
#     H --> E
# ```
#
# **Key Benefits:**
# - **⚡ Performance**: Significant speedup through parallel execution
# - **📈 Scalability**: Handle increased workloads without proportional time increase
# - **🔄 Efficiency**: Better utilization of available computational resources
# - **🎯 Throughput**: Process more work in the same amount of time
#
# ## 🎨 **Concurrent Workflow Design Patterns**
#
# ### 🔍 **Research & Analysis Pipeline**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Data Processing Workflow**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Content Creation Pipeline**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Multi-Stage Processing**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Enterprise Performance Benefits**
#
# ### ⚡ **Throughput Optimization**
# - **Parallel Execution**: Multiple agents working simultaneously
# - **Resource Utilization**: Maximum efficiency of available AI model capacity
# - **Time Reduction**: Significant decrease in total processing time
# - **Scalable Architecture**: Easily add more concurrent agents as needed
#
# ### 🛡️ **Reliability & Resilience**
# - **Fault Tolerance**: Individual agent failures don't stop the entire workflow
# - **Error Isolation**: Problems in one concurrent branch don't affect others
# - **Graceful Degradation**: System continues operating even with reduced agent capacity
# - **Recovery Mechanisms**: Automatic retry and error handling for failed operations
#
# ### 📊 **Monitoring & Observability**
# - **Concurrent Execution Tracking**: Monitor progress of all parallel operations
# - **Performance Metrics**: Measure speedup and efficiency gains
# - **Resource Usage Analytics**: Optimize concurrent agent allocation
# - **Bottleneck Identification**: Find and resolve performance constraints
#
# Let's build high-performance concurrent AI workflows! 🚀

# %%
! sudo apt update 
! sudo apt install graphviz -y
# Out:
# Hit:1 http://deb.debian.org/debian bookworm InRelease
# Hit:2 http://deb.debian.org/debian bookworm-updates InRelease
# Hit:3 http://deb.debian.org/debian-security bookworm-security InRelease
# Hit:4 https://dl.yarnpkg.com/debian stable InRelease
# Hit:5 https://packages.microsoft.com/repos/azure-cli bookworm InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# All packages are up to date.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-7+deb12u1).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %%
! pip install agent-framework-core -U
! pip install agent-framework[viz] -U
! pip install graphviz -U
# Out:
# Requirement already satisfied: agent-framework-core in /opt/conda/lib/python3.12/site-packages (1.0.0b251001)
# Requirement already satisfied: openai>=1.99.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (1.109.1)
# Requirement already satisfied: pydantic<3,>=2 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (2.11.9)
# Requirement already satisfied: pydantic-settings<3,>=2 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (2.11.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: opentelemetry-api>=1.24 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.24 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (1.37.0)
# Requirement already satisfied: mcp>=1.13 in /opt/conda/lib/python3.12/site-packages (from mcp[ws]>=1.13->agent-framework-core) (1.16.0)
# Requirement already satisfied: azure-monitor-opentelemetry>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (1.8.1)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter>=1.0.0b41 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (1.0.0b42)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.36.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (0.4.13)
# Requirement already satisfied: aiofiles>=24.1.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (24.1.0)
# Requirement already satisfied: azure-identity<2,>=1 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (1.25.0)
# Requirement already satisfied: azure-core>=1.31.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.35.1)
# Requirement already satisfied: cryptography>=2.5 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.2)
# Requirement already satisfied: msal>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.12/site-packages (from pydantic-settings<3,>=2->agent-framework-core) (1.1.1)
# Requirement already satisfied: requests>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.4)
# Requirement already satisfied: six>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (1.17.0)
# Requirement already satisfied: azure-core-tracing-opentelemetry~=1.0.0b11 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (1.0.0b12)
# Requirement already satisfied: opentelemetry-instrumentation-django~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-flask~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-requests~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-resource-detector-azure~=0.1.5 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.1.5)
# Requirement already satisfied: fixedint==0.1.6 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (0.1.6)
# Requirement already satisfied: msrest>=0.6.10 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (0.7.1)
# Requirement already satisfied: psutil<8,>=5.9 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (7.1.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api>=1.24->agent-framework-core) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.24->agent-framework-core) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-wsgi==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-util-http==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (25.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (1.17.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: asgiref~=3.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.58b0->opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (3.9.2)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-psycopg2~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.22)
# Requirement already satisfied: anyio>=4.5 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.4.1)
# Requirement already satisfied: httpx>=0.27.1 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (4.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.48.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.37.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.12/site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (1.3.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.27.1)
# Requirement already satisfied: websockets>=15.0.1 in /opt/conda/lib/python3.12/site-packages (from mcp[ws]>=1.13->agent-framework-core) (15.0.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity<2,>=1->agent-framework-core) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.5.0)
# Requirement already satisfied: isodate>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (0.7.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /opt/conda/lib/python3.12/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (2.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core) (0.11.0)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core) (4.67.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.75.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.37.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-proto==1.37.0->opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (5.29.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (3.3.1)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (8.3.0)
# Requirement already satisfied: agent-framework[viz] in /opt/conda/lib/python3.12/site-packages (1.0.0b251001)
# WARNING: agent-framework 1.0.0b251001 does not provide the extra 'viz'
# Requirement already satisfied: agent-framework-core in /opt/conda/lib/python3.12/site-packages (from agent-framework[viz]) (1.0.0b251001)
# Requirement already satisfied: agent-framework-a2a in /opt/conda/lib/python3.12/site-packages (from agent-framework[viz]) (1.0.0b251001)
# Requirement already satisfied: agent-framework-azure-ai in /opt/conda/lib/python3.12/site-packages (from agent-framework[viz]) (1.0.0b251001)
# Requirement already satisfied: agent-framework-copilotstudio in /opt/conda/lib/python3.12/site-packages (from agent-framework[viz]) (1.0.0b251001)
# Requirement already satisfied: agent-framework-mem0 in /opt/conda/lib/python3.12/site-packages (from agent-framework[viz]) (1.0.0b251001)
# Requirement already satisfied: agent-framework-redis in /opt/conda/lib/python3.12/site-packages (from agent-framework[viz]) (1.0.0b251001)
# Requirement already satisfied: agent-framework-devui in /opt/conda/lib/python3.12/site-packages (from agent-framework[viz]) (1.0.0b251001)
# Requirement already satisfied: a2a-sdk>=0.3.5 in /opt/conda/lib/python3.12/site-packages (from agent-framework-a2a->agent-framework[viz]) (0.3.7)
# Requirement already satisfied: google-api-core>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (2.25.2)
# Requirement already satisfied: httpx-sse>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (0.4.1)
# Requirement already satisfied: httpx>=0.28.1 in /opt/conda/lib/python3.12/site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (0.28.1)
# Requirement already satisfied: protobuf>=5.29.5 in /opt/conda/lib/python3.12/site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (5.29.5)
# Requirement already satisfied: pydantic>=2.11.3 in /opt/conda/lib/python3.12/site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (2.11.9)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (1.70.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/conda/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/conda/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (2.41.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /opt/conda/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (2.32.4)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (0.6.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx>=0.28.1->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.28.1->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.28.1->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic>=2.11.3->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.12/site-packages (from pydantic>=2.11.3->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.12/site-packages (from pydantic>=2.11.3->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic>=2.11.3->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (0.4.2)
# Requirement already satisfied: azure-ai-projects>=1.0.0b11 in /opt/conda/lib/python3.12/site-packages (from agent-framework-azure-ai->agent-framework[viz]) (1.1.0b4)
# Requirement already satisfied: azure-ai-agents==1.2.0b5 in /opt/conda/lib/python3.12/site-packages (from agent-framework-azure-ai->agent-framework[viz]) (1.2.0b5)
# Requirement already satisfied: aiohttp~=3.8 in /opt/conda/lib/python3.12/site-packages (from agent-framework-azure-ai->agent-framework[viz]) (3.12.15)
# Requirement already satisfied: isodate>=0.6.1 in /opt/conda/lib/python3.12/site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai->agent-framework[viz]) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai->agent-framework[viz]) (1.35.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework[viz]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework[viz]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework[viz]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework[viz]) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework[viz]) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework[viz]) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework[viz]) (1.20.1)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-projects>=1.0.0b11->agent-framework-azure-ai->agent-framework[viz]) (12.26.0)
# Requirement already satisfied: six>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai->agent-framework[viz]) (1.17.0)
# Requirement already satisfied: cryptography>=2.1.4 in /opt/conda/lib/python3.12/site-packages (from azure-storage-blob>=12.15.0->azure-ai-projects>=1.0.0b11->agent-framework-azure-ai->agent-framework[viz]) (46.0.2)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects>=1.0.0b11->agent-framework-azure-ai->agent-framework[viz]) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects>=1.0.0b11->agent-framework-azure-ai->agent-framework[viz]) (2.22)
# Requirement already satisfied: microsoft-agents-copilotstudio-client>=0.3.1 in /opt/conda/lib/python3.12/site-packages (from agent-framework-copilotstudio->agent-framework[viz]) (0.3.2)
# Requirement already satisfied: microsoft-agents-hosting-core==0.3.2 in /opt/conda/lib/python3.12/site-packages (from microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework[viz]) (0.3.2)
# Requirement already satisfied: microsoft-agents-activity==0.3.2 in /opt/conda/lib/python3.12/site-packages (from microsoft-agents-hosting-core==0.3.2->microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework[viz]) (0.3.2)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/conda/lib/python3.12/site-packages (from microsoft-agents-hosting-core==0.3.2->microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework[viz]) (2.10.1)
# Requirement already satisfied: python-dotenv>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from microsoft-agents-hosting-core==0.3.2->microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework[viz]) (1.1.1)
# Requirement already satisfied: openai>=1.99.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework[viz]) (1.109.1)
# Requirement already satisfied: pydantic-settings<3,>=2 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework[viz]) (2.11.0)
# Requirement already satisfied: opentelemetry-api>=1.24 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework[viz]) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.24 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework[viz]) (1.37.0)
# Requirement already satisfied: mcp>=1.13 in /opt/conda/lib/python3.12/site-packages (from mcp[ws]>=1.13->agent-framework-core->agent-framework[viz]) (1.16.0)
# Requirement already satisfied: azure-monitor-opentelemetry>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework[viz]) (1.8.1)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter>=1.0.0b41 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework[viz]) (1.0.0b42)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.36.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework[viz]) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework[viz]) (0.4.13)
# Requirement already satisfied: aiofiles>=24.1.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework[viz]) (24.1.0)
# Requirement already satisfied: azure-identity<2,>=1 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework[viz]) (1.25.0)
# Requirement already satisfied: msal>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core->agent-framework[viz]) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core->agent-framework[viz]) (1.3.1)
# Requirement already satisfied: azure-core-tracing-opentelemetry~=1.0.0b11 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (1.0.0b12)
# Requirement already satisfied: opentelemetry-instrumentation-django~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-flask~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-requests~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.58b0)
# Requirement already satisfied: opentelemetry-resource-detector-azure~=0.1.5 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.1.5)
# Requirement already satisfied: fixedint==0.1.6 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework[viz]) (0.1.6)
# Requirement already satisfied: msrest>=0.6.10 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework[viz]) (0.7.1)
# Requirement already satisfied: psutil<8,>=5.9 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework[viz]) (7.1.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api>=1.24->agent-framework-core->agent-framework[viz]) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.24->agent-framework-core->agent-framework[viz]) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-wsgi==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.58b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.58b0)
# Requirement already satisfied: opentelemetry-util-http==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.58b0)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (25.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (1.17.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.58b0)
# Requirement already satisfied: asgiref~=3.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.58b0->opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (3.9.2)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-psycopg2~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework[viz]) (0.58b0)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework[viz]) (4.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework[viz]) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework[viz]) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework[viz]) (0.48.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework[viz]) (0.37.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio->httpx>=0.28.1->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework[viz]) (1.3.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework[viz]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework[viz]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework[viz]) (0.27.1)
# Requirement already satisfied: websockets>=15.0.1 in /opt/conda/lib/python3.12/site-packages (from mcp[ws]>=1.13->agent-framework-core->agent-framework[viz]) (15.0.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /opt/conda/lib/python3.12/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework[viz]) (2.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core->agent-framework[viz]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core->agent-framework[viz]) (0.11.0)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core->agent-framework[viz]) (4.67.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework[viz]) (1.75.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework[viz]) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework[viz]) (1.37.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework[viz]) (3.3.1)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework[viz]) (8.3.0)
# Requirement already satisfied: fastapi>=0.104.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-devui->agent-framework[viz]) (0.118.0)
# Requirement already satisfied: httptools>=0.6.3 in /opt/conda/lib/python3.12/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework[viz]) (0.6.4)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.12/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework[viz]) (6.0.3)
# Requirement already satisfied: uvloop>=0.15.1 in /opt/conda/lib/python3.12/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework[viz]) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/conda/lib/python3.12/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework[viz]) (1.1.0)
# Requirement already satisfied: mem0ai>=0.1.117 in /opt/conda/lib/python3.12/site-packages (from agent-framework-mem0->agent-framework[viz]) (0.1.118)
# Requirement already satisfied: posthog>=3.5.0 in /opt/conda/lib/python3.12/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework[viz]) (6.7.6)
# Requirement already satisfied: pytz>=2024.1 in /opt/conda/lib/python3.12/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework[viz]) (2025.2)
# Requirement already satisfied: qdrant-client>=1.9.1 in /opt/conda/lib/python3.12/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework[viz]) (1.15.1)
# Requirement already satisfied: sqlalchemy>=2.0.31 in /opt/conda/lib/python3.12/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework[viz]) (2.0.43)
# Requirement already satisfied: python-dateutil>=2.2 in /opt/conda/lib/python3.12/site-packages (from posthog>=3.5.0->mem0ai>=0.1.117->agent-framework-mem0->agent-framework[viz]) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /opt/conda/lib/python3.12/site-packages (from posthog>=3.5.0->mem0ai>=0.1.117->agent-framework-mem0->agent-framework[viz]) (2.2.1)
# Requirement already satisfied: numpy>=1.26 in /opt/conda/lib/python3.12/site-packages (from qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework[viz]) (2.3.3)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /opt/conda/lib/python3.12/site-packages (from qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework[viz]) (3.2.0)
# Requirement already satisfied: h2<5,>=3 in /opt/conda/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework[viz]) (4.2.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /opt/conda/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework[viz]) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /opt/conda/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework[viz]) (4.1.0)
# Requirement already satisfied: greenlet>=1 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy>=2.0.31->mem0ai>=0.1.117->agent-framework-mem0->agent-framework[viz]) (3.2.4)
# Requirement already satisfied: redis>=6.4.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-redis->agent-framework[viz]) (6.4.0)
# Requirement already satisfied: redisvl>=0.8.2 in /opt/conda/lib/python3.12/site-packages (from agent-framework-redis->agent-framework[viz]) (0.9.1)
# Requirement already satisfied: jsonpath-ng>=1.5.0 in /opt/conda/lib/python3.12/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework[viz]) (1.7.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework[viz]) (0.5.3)
# Requirement already satisfied: python-ulid>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework[viz]) (3.1.0)
# Requirement already satisfied: tenacity>=8.2.2 in /opt/conda/lib/python3.12/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework[viz]) (9.1.2)
# Requirement already satisfied: ply in /opt/conda/lib/python3.12/site-packages (from jsonpath-ng>=1.5.0->redisvl>=0.8.2->agent-framework-redis->agent-framework[viz]) (3.11)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.12/site-packages (0.21)

# %%
import os
from typing import Any

from agent_framework import ChatMessage, ConcurrentBuilder,WorkflowViz
from agent_framework.openai import OpenAIChatClient

# %%
chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id="gpt-4o" )

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent   = chat_client.create_agent(
        instructions=(
           ResearcherAgentInstructions
        ),
        name=ResearcherAgentName,
    )

plan_agent = chat_client.create_agent(
        instructions=(
            PlanAgentInstructions
        ),
        name=PlanAgentName,
    )

# %%
workflow = ConcurrentBuilder().participants([research_agent, plan_agent]).build()

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
svg_file = viz.export(format="svg")
print(f"SVG file saved to: {svg_file}")
# Out:
# Generating workflow visualization...
# Mermaid string:
# =======
# flowchart TD
#   dispatcher["dispatcher (Start)"];
#   Researcher_Agent["Researcher-Agent"];
#   Plan_Agent["Plan-Agent"];
#   aggregator["aggregator"];
#   fan_in__aggregator__69d73de8((fan-in))
#   Plan_Agent --> fan_in__aggregator__69d73de8;
#   Researcher_Agent --> fan_in__aggregator__69d73de8;
#   fan_in__aggregator__69d73de8 --> aggregator;
#   dispatcher --> Researcher_Agent;
#   dispatcher --> Plan_Agent;
# =======
# DiGraph string:
# =======
# digraph Workflow {
#   rankdir=TD;
#   node [shape=box, style=filled, fillcolor=lightblue];
#   edge [color=black, arrowhead=vee];
#
#   "dispatcher" [fillcolor=lightgreen, label="dispatcher\n(Start)"];
#   "Researcher-Agent" [label="Researcher-Agent"];
#   "Plan-Agent" [label="Plan-Agent"];
#   "aggregator" [label="aggregator"];
#
#   "fan_in::aggregator::69d73de8" [shape=ellipse, fillcolor=lightgoldenrod, label="fan-in"];
#   "Plan-Agent" -> "fan_in::aggregator::69d73de8";
#   "Researcher-Agent" -> "fan_in::aggregator::69d73de8";
#   "fan_in::aggregator::69d73de8" -> "aggregator";
#   "dispatcher" -> "Researcher-Agent";
#   "dispatcher" -> "Plan-Agent";
# }
# =======
# SVG file saved to: /tmp/tmpinml21lt.svg

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")
# Out:
# Attempting to display SVG file at: /tmp/tmpinml21lt.svg

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
        print("===== Final Aggregated Conversation (messages) =====")
        for output in outputs:
            messages: list[ChatMessage] | Any = output
            for i, msg in enumerate(messages, start=1):
                name = msg.author_name if msg.author_name else "user"
                print(f"{'-' * 60}\n\n{i:02d} [{name}]:\n{msg.text}")
# Out:
# ===== Final Aggregated Conversation (messages) =====
# ------------------------------------------------------------
#
# 01 [user]:
# Plan a trip to Seattle in December
# ------------------------------------------------------------
#
# 02 [Researcher-Agent]:
# Seattle in December offers a mix of cozy indoor adventures, festive holiday activities, and opportunities to experience the city’s iconic landmarks. The weather will likely be chilly, and rain is common, so packing warm, waterproof clothing is essential. Below is a detailed plan for your trip, broken down by attraction and activity:
#
# ---
#
# ### **DAY 1: Explore the Waterfront & Iconic Landmarks**
#
# #### **Attractions:**
# 1. **Pike Place Market**
#    - **What to Do:**
#      - Browse the artisan stalls and shop for unique, handmade gifts.
#      - Watch fishmongers toss fresh seafood at the market’s famous "flying fish" spot.
#      - Stop by the **Original Starbucks**, grab a coffee, and learn about its history.
#      - Visit the **MarketFront Pavilion** for stunning Elliott Bay views.
#    - **Time Needed**: 2–3 hours.
#    - **Insider Tip**: Arrive early to beat the crowds and enjoy market shopping while vendors are setting up.
#
# 2. **Seattle Great Wheel**
#    - **What to Do:**
#      - Ride the massive ferris wheel located directly on the waterfront for panoramic views of Puget Sound, the Olympic Mountains, and the city skyline. The gondolas are enclosed and heated—perfect for winter.
#    - **Time Needed**: 45 minutes (including wait line).
#
# 3. **Waterfront Attractions**
#    - **What to Do:**
#      - Stroll along the Seattle Waterfront and enjoy shops, eateries, and outdoor art installations.
#      - Visit the **Seattle Aquarium** to see otters, coral reefs, and other marine life.
#
# #### **Dinner Suggestion**:
# - **Elliott’s Oyster House**: Enjoy fresh seafood with waterfront views. Their clam chowder is perfect on chilly days.
#
# ---
#
# ### **DAY 2: Museums & Downtown Landmarks**
#
# #### **Attractions:**
# 1. **Museum of Pop Culture (MoPOP)**
#    - **What to Do**:
#      - Dive into exhibits featuring music icons (Nirvana, Jimi Hendrix), sci-fi films, gaming memorabilia, and more.
#      - Check out seasonal displays—MoPOP often features holiday-themed events or exhibits.
#    - **Time Needed**: 2–3 hours.
#
# 2. **Chihuly Garden and Glass**
#    - **What to Do**:
#      - Marvel at Dale Chihuly’s intricate glass art installations indoors and outdoors in the garden.
#      - Check out seasonal holiday decorations and stunning nighttime light displays.
#    - **Time Needed**: 1–2 hours.
#    - **Insider Tip**: Bundle tickets with MoPOP or Space Needle to save money.
#
# 3. **Space Needle**
#    - **What to Do**:
#      - Take the elevator up to the observation deck for breathtaking views of the city, nearby mountains, and water while the city twinkles below at night.
#    - **Time Needed**: 1 hour.
#
# #### **Dinner Suggestion**:
# - **The Pink Door**: Hidden behind an unmarked door near Pike Place, it offers Italian-inspired dishes in a warm and eclectic atmosphere.
#
# ---
#
# ### **DAY 3: Holiday Cheer & Neighborhoods**
#
# #### **Attractions:**
#
# 1. **Downtown Lights & Holiday Festivities**
#    - **What to Do**:
#      - Visit **Westlake Park** for local holiday pop-ups and lights. Often there’s a holiday carousel and seasonal ice rink operating nearby. (**Check for opening dates**).
#      - Walk along downtown streets like 5th Avenue to enjoy holiday lights and window displays.
#
# 2. **Ballard Neighborhood & Locks** (*Optional Morning Adventure*)
#    - **What to Do**:
#      - Visit the **Ballard Locks**, where you can watch boats travel between Puget Sound and inland waterways.
#      - Walk through **Carl S. English Jr. Botanical Garden**, offering serene winter scenery.
#    - **Time Needed**: 2 hours.
#
# 3. **Capitol Hill Exploration**
#    - **What to Do**:
#      - Visit **The Elliot Bay Book Company**, a cozy independent bookstore great for browsing on a cold day.
#      - Explore nearby coffee shops—like **Espresso Vivace** or **Victrola Coffee**.
#      - Grab dinner or late-night bites at **Tacos Chukis**, a hidden gem with great Mexican street tacos.
#
# #### **Dinner Suggestion**:
# - **Canlis**: Splurge on this upscale dining experience with exquisite views and high-end seasonal offerings.
#
# ---
#
# ### **DAY 4: Day Trip Options**
# Seattle’s location makes it easy to take memorable day trips—even in December. You can choose one:
#
# #### **Option 1: Snoqualmie Falls (+ Wine Tasting in Woodinville)**
#    - **What to Do**:
#      - Drive 40 minutes east to see the majestic Snoqualmie Falls, which looks stunning surrounded by mist and snow in winter.
#      - Afterward, head to **Woodinville Wine Country** to visit a few local wineries such as **Chateau Ste. Michelle** or **Columbia Winery** for tastings.
#
# #### **Option 2: Bainbridge Island**
#    - **What to Do**:
#      - Take a ferry to Bainbridge Island for picturesque views of Puget Sound during the ride.
#      - Stroll through Winslow, the island’s charming downtown with galleries, boutiques, and coffee shops.
#      - Visit **Bloedel Reserve**—an enchanting nature preserve with forest trails and gardens (beautiful, even in winter).
#
# #### **Option 3: Leavenworth (Festive Holiday Village)**
#    - **What to Do**:
#      - Drive about 2 hours to explore this Bavarian-themed village decked out with incredible holiday lights and decoration.
#      - Enjoy activities like holiday markets, sledding, or caroling, plus shops and restaurants serving German-inspired cuisine.
#
# ---
#
# ### **Packing Tips for Seattle in December**
# - Waterproof jacket or coat.
# - Layered clothing (sweaters, scarves, gloves).
# - Comfortable waterproof shoes.
# - Umbrella (optional but recommended).
# - Reusable water bottle and day bag for city exploring.
#
# With this itinerary, you'll experience Seattle’s festive holiday spirit, iconic landmarks, cultural attractions, and nearby natural beauty! Let me know if you'd like to adjust or prioritize certain activities.
# ------------------------------------------------------------
#
# 03 [Plan-Agent]:
# Absolutely! Seattle in December is a magical destination, offering a mix of holiday cheer, iconic sights, and cozy indoor activities to counter the cool, rainy weather. Here’s a detailed travel plan for your trip to Seattle:
#
# ---
#
# ### Trip Overview:
# - **Duration:** 5 Days (flexible depending on your preference)
# - **Weather:** Expect temperatures between **37-47°F (3-8°C)**, with frequent rain. Pack warm clothing, waterproof gear, and comfortable footwear.
# - **Highlights:** Holiday markets, iconic landmarks, cozy cafes, and cultural experiences.
#
# ---
#
# ### **Day 1: Arrival and Exploring Downtown**
# - **Arrive in Seattle**
#   - **Airport:** Seattle-Tacoma International Airport (SEA)
#   - Transportation options: Take the **Link Light Rail** to downtown ($3 fare, 40 minutes), or taxi/rideshare for convenience.
# - **Hotel Check-in:** Stay in downtown Seattle for easy access to attractions. Recommendations:
#   - Mid-range: **The Paramount Hotel** or **The Maxwell Hotel**.
#   - Luxury: **Fairmont Olympic Hotel** or **Four Seasons Seattle**.
# - **Afternoon: Pike Place Market**
#   - Stroll through the historic **Pike Place Market**, perfect for shopping, snacks, artisan crafts, and fresh seafood. Don’t miss:
#     - The **fish-throwing vendors.**
#     - **Beecher’s Handmade Cheese** for mac and cheese.
#     - **Rachel the Piggy Bank** for a photo-op.
#     - The quirky **Gum Wall** in Post Alley.
# - **Dinner:** Dine at **The Pink Door** (Italian-American cuisine with a cozy, romantic vibe).
# - **Evening:** Walk along the **Seattle Waterfront** and enjoy the festive lights. Visit spots like the **Seattle Great Wheel**, lit up for the holidays.
#
# ---
#
# ### **Day 2: Landmarks and Architecture**
# - **Morning:** Space Needle & Chihuly Garden and Glass
#   - Visit the **Space Needle** for panoramic views of the city and Puget Sound.
#   - Explore the adjacent **Chihuly Garden and Glass**, showcasing stunning glass art installations.
# - **Lunch:** Eat at **Collections Café** near Chihuly or **Tilikum Place Café** (Dutch-inspired pancakes).
# - **Afternoon:** Museum of Pop Culture (MoPOP)
#   - Dive into pop culture, science fiction, and music exhibits. This is a fun, interactive museum for all ages.
# - **Evening:** Enjoy happy hour at **The Nest**, a rooftop lounge, or cozy up with dinner at **Matt’s in the Market**.
# - **Optional Evening Activity:**
#   - Watch an indie film at **SIFF Cinema Uptown**, or see live jazz at **Dimitriou’s Jazz Alley**.
#
# ---
#
# ### **Day 3: Holiday Spirit and Neighborhood Strolls**
# - **Morning:** Holiday Markets & Coffee Culture
#   - Warm up with a cup of Seattle’s iconic coffee at **Storyville Coffee** (near Pike Place) or the **Starbucks Reserve Roastery** in Capitol Hill.
#   - Visit a festive **holiday market** — check out **Seattle Christmas Market** or **Enchant Christmas** at T-Mobile Park (a dazzling light maze and Christmas-themed experience).
# - **Afternoon:** Capitol Hill Exploration
#   - Capitol Hill is full of boutiques, vintage shops, and art galleries. Don’t miss **Elliott Bay Book Company**, a local gem.
#   - Lunch at **Tallulah’s** or grab a seasonal pastry at **Bakery Nouveau**.
# - **Evening:** Light Displays
#   - Head to **Woodland Park Zoo’s WildLanterns** (a magical holiday lantern festival).
#   - Alternatively, visit the **Bellevue Botanical Garden’s Garden d’Lights** (30-minute drive east of Seattle) for a stunning winter lights experience.
# - **Dinner:** Try **Elliott’s Oyster House** on the waterfront for fresh seafood in a festive setting.
#
# ---
#
# ### **Day 4: Nature & Outdoors**
# - **Morning:** Kerry Park & Discovery Park
#   - Start your day at **Kerry Park** for breathtaking views of the Seattle skyline.
#   - Explore **Discovery Park**, Seattle’s largest green space, where you can take short trails leading to scenic views of Puget Sound.
# - **Lunch:** Head to **Westward**, a waterfront restaurant with views of North Lake Union.
# - **Afternoon:** Fremont & Ballard Neighborhoods
#   - Fremont: Visit the quirky shops, **Fremont Troll**, and **Theo Chocolate Factory** (tours available).
#   - Ballard: Walk through the historic **Ballard Locks** and fish ladder. If it’s a weekend, check out the **Ballard Farmers Market.**
# - **Evening:** Breweries & Dinner in Ballard
#   - Ballard is home to fantastic craft breweries like **Reuben’s Brews** or **Stoup Brewing**.
#   - Enjoy dinner at **The Walrus and the Carpenter**, a highly-rated oyster bar.
#
# ---
#
# ### **Day 5: Waterfront Attractions & Departure**
# - **Morning:** Seattle Aquarium & Waterfront Parks
#   - Visit the **Seattle Aquarium**, then take a relaxing walk through **Olympic Sculpture Park** or along the waterfront promenade.
# - **Optional:** Take a **Harbor Cruise** or a short ferry ride to Bainbridge Island for beautiful Puget Sound views.
# - **Lunch:** Try **Ivar’s Acres of Clams** for waterfront dining with iconic clam chowder.
# - **Afternoon:** Last-Minute Shopping
#   - Stop by **Pacific Place** mall or **Pioneer Square** for artisanal gifts and souvenirs unique to Seattle.
# - **Evening:** Depart Seattle
#   - Head to SEA-TAC Airport using your preferred transportation.
#
# ---
#
# ### Tips for Traveling to Seattle in December:
# - **Rain Prep:** Always carry a small umbrella, waterproof jacket, and shoes. Quick-drying layers work great.
# - **Transportation:** Use public transit or rideshares to navigate. Seattle is walkable in many areas and has efficient buses, light rail, and ferries.
# - **Reservations:** December is a busy time with holiday activities, so book popular attractions (Space Needle, Chihuly, MoPOP) and restaurants in advance!
# - **Local Experiences:** Don’t skip cozying up with coffee (Seattle’s coffee culture is unmatched) or visiting the festive neighborhoods to see Christmas lights.
#
# Let me know if you want to adjust the focus of your trip (e.g., more outdoor activities, dining experiences, or family-friendly options)!
