# %% [markdown]
# # 🌟 Create Your First AI Agent with GitHub Models (.NET)
#
# ## 📖 Tutorial Overview
#
# This comprehensive tutorial guides you through creating your first intelligent AI agent using the Microsoft Agent Framework for .NET. You'll build a sophisticated travel planning assistant that leverages GitHub Models to generate personalized vacation itineraries.
#
# **Learning Goals:**
# - 🚀 **Agent Creation**: Build a complete AI agent from scratch
# - 🔧 **GitHub Models Integration**: Connect to GitHub's model inference service
# - 🛠️ **Tool Development**: Create custom tools for your agent
# - 📝 **Best Practices**: Learn production-ready patterns and configurations
#
# ## 🏗️ What You'll Build
#
# A fully functional travel agent that can:
# - Select random vacation destinations using a custom tool
# - Generate detailed day-trip itineraries with local recommendations
# - Provide real-time streaming responses for better user experience
# - Handle multiple conversation turns with context awareness
#
# ## 🔧 Technical Architecture
#
# ### Framework Components
# - **Microsoft.Extensions.AI**: Core AI abstraction layer for .NET
# - **Microsoft.Agents.AI**: Agent orchestration and management system
# - **GitHub Models API**: Access to state-of-the-art language models
# - **OpenAI Client**: Standardized API patterns for model interaction
#
# ### Integration Pattern
# ```csharp
# AIAgent → OpenAI Client → GitHub Models API ← Custom Tools
#     ↓           ↓              ↓               ↓
# User ← Response ← LLM ← Tool Execution ← GetRandomDestination()
# ```
#
# ### Key Features Demonstrated
# - **Environment-based Configuration**: Secure API key management
# - **Custom Tool Integration**: Extending agent capabilities with C# methods
# - **Streaming Responses**: Real-time response generation
# - **Error Handling**: Robust configuration validation
#
# ## ⚙️ Prerequisites
#
# **Development Environment:**
# - .NET 9.0 SDK or higher
# - Visual Studio 2022 or VS Code with C# extension
# - GitHub Models API access
#
# **Required Configuration (.env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎯 Step-by-Step Process
#
# 1. **Setup Dependencies**: Reference required NuGet packages and assemblies
# 2. **Configure Environment**: Load secure configuration from .env file
# 3. **Define Tools**: Create custom functions for the agent to use
# 4. **Initialize Client**: Set up GitHub Models API connection
# 5. **Create Agent**: Build the AI agent with instructions and tools
# 6. **Execute Requests**: Run travel planning scenarios
# 7. **Handle Responses**: Process both streaming and non-streaming outputs
#
# Ready to build your first intelligent agent? Let's get started! 🚀

# %%
// 📦 NuGet Package: Microsoft Extensions AI
// Core AI abstraction layer providing unified interfaces for AI services
// Essential foundation for building AI applications in .NET ecosystem
#r "nuget: Microsoft.Extensions.AI, 9.9.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.0</span></li></ul></div></div>

# %%
// 🤖 Local Reference: Microsoft Agents AI OpenAI Integration
// OpenAI-specific implementations for the Microsoft Agent Framework
// Provides seamless integration with OpenAI models and GitHub Models API
// Note: Using local development build for latest features
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.OpenAI\bin\Debug\net9.0\Microsoft.Agents.AI.OpenAI.dll"

# %%
// 🏗️ Local Reference: Core Microsoft Agents AI Framework
// Fundamental agent abstractions and base classes
// Provides the essential building blocks for creating intelligent agents
// Contains the core AIAgent class and orchestration logic
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI\bin\Debug\net9.0\Microsoft.Agents.AI.dll"

# %%
// 🔌 NuGet Package: Microsoft Extensions AI OpenAI (Preview)
// Preview version providing enhanced OpenAI integration capabilities
// Includes latest features for AI agent development and model connectivity
#r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4</span></li></ul></div></div>

# %%
// 🔧 NuGet Package: Environment Variable Management
// DotNetEnv enables loading configuration from .env files
// Essential for secure API key management and development workflows
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
// 📚 Import Required Namespaces
// Core system functionality and framework components

using System;                          // Fundamental .NET types and functionality
using System.ComponentModel;           // Description attributes for tool functions
using System.ClientModel;             // Client abstractions for API communication

using Microsoft.Extensions.AI;        // AI service abstractions and interfaces
using Microsoft.Agents.AI;           // Agent framework core classes
using OpenAI;                         // OpenAI client library integration

# %%
// 🔧 Import Environment Variable Loading
// Enable secure configuration management from external files
using DotNetEnv;

# %%
// 🔐 Load Environment Configuration
// Initialize API credentials and configuration from .env file
// Ensures secure handling of sensitive information
Env.Load("../../../.env");

# %%
// 🎯 Agent Tool: Random Destination Generator
// Custom tool function that the agent can invoke to suggest travel destinations
// The Description attribute helps the AI understand when to use this function

[Description("Provides a random vacation destination for travel planning.")]
static string GetRandomDestination()
{
    // 🌍 Curated collection of world-class travel destinations
    // Each destination offers unique experiences and cultural attractions
    var destinations = new List<string>
    {
        "Paris, France",           // 🗼 European culture & romance
        "Tokyo, Japan",            // 🏙️ Modern technology & tradition
        "New York City, USA",      // 🌆 Urban energy & diversity
        "Sydney, Australia",       // 🏖️ Iconic harbors & lifestyle
        "Rome, Italy",             // 🏛️ Ancient history & cuisine
        "Barcelona, Spain",        // 🎨 Mediterranean art & architecture
        "Cape Town, South Africa", // 🏔️ Stunning landscapes & wine
        "Rio de Janeiro, Brazil",  // 🏖️ Beaches & carnival culture
        "Bangkok, Thailand",       // 🏯 Southeast Asian heritage
        "Vancouver, Canada"        // 🍁 Natural beauty & outdoor adventures
    };

    // 🎲 Generate random selection for inspiring travel suggestions
    var random = new Random();
    int index = random.Next(destinations.Count);
    return destinations[index];
}

# %%
// 🔑 Extract GitHub Models Configuration
// Retrieve and validate required environment variables for API access
var github_endpoint = Environment.GetEnvironmentVariable("GITHUB_ENDPOINT") ?? throw new InvalidOperationException("GITHUB_ENDPOINT is required");
var github_model_id = Environment.GetEnvironmentVariable("GITHUB_MODEL_ID") ?? "gpt-4o-mini";  // Default to efficient model
var github_token = Environment.GetEnvironmentVariable("GITHUB_TOKEN") ?? throw new InvalidOperationException("GITHUB_TOKEN is required");

# %%
// ⚙️ Configure OpenAI Client for GitHub Models
// Set up client options to redirect API calls to GitHub Models endpoint
var openAIOptions = new OpenAIClientOptions()
{
    Endpoint = new Uri(github_endpoint)  // 🔗 Point to GitHub Models infrastructure
};

# %%
// 🤖 Create Your First AI Agent!
// Initialize a complete AI agent with GitHub Models integration and custom tools
AIAgent agent = new OpenAIClient(new ApiKeyCredential(github_token), openAIOptions)
    .GetChatClient(github_model_id)  // 🎯 Connect to specified AI model
    .CreateAIAgent(
        instructions: "You are a helpful AI Agent that can help plan vacations for customers at random destinations",  // 📝 Agent personality
        tools: [AIFunctionFactory.Create((Func<string>)GetRandomDestination)]  // 🛠️ Register custom tools
    );

# %%
// 🚀 Test Your Agent - Generate Travel Plan
// Execute the agent with a travel planning request
// The agent will intelligently use the GetRandomDestination tool as needed
Console.WriteLine(await agent.RunAsync("Plan me a day trip"));
# Out:
# I've planned a day trip for you to Vancouver, Canada! Here's a mix of activities and sights to make the most of your day:
#
# ### Morning:
# - **Breakfast at a Local Café**: Start your day with breakfast at a local favorite, like "Café Artigiano" for some great coffee and pastries.
# - **Stanley Park**: Visit Stanley Park for a morning stroll. You can walk or rent a bike to explore the seawall and see beautiful views of the city and mountains. Don't miss the Totem Poles!
#
# ### Midday:
# - **Granville Island Public Market**: Head over to Granville Island for lunch. The Public Market offers a variety of fresh local produce, artisanal foods, and delicious food stalls. Enjoy lunch with a view of the waterfront.
# - **Explore Granville Island**: After lunch, take some time to explore the shops, galleries, and artisan studios in the area.
#
# ### Afternoon:
# - **Capilano Suspension Bridge Park**: Extend your adventure by visiting the Capilano Suspension Bridge. Walk across the famous bridge and enjoy the breathtaking views. Explore the treetop walk and learn about the area’s history.
#
# ### Evening:
# - **Dinner in Yaletown**: Head back toward downtown and dine in Yaletown, known for its trendy restaurants. Consider places like "Blue Water Cafe" or "The Keg" for a nice dinner experience.
# - **Sunset at English Bay Beach**: After dinner, take a relaxing stroll to English Bay Beach to watch the sunset. It’s a perfect way to end your day in Vancouver.
#
# ### Optional Night Activity:
# - If you’re up for it, unwind at one of Vancouver's local breweries or go for a walk along the lively streets of Gastown, where you can see the famous steam clock and enjoy the vibrant nightlife.
#
# Enjoy your day trip to Vancouver! Let me know if you need more information or assistance.

# %%
// 🌊 Experience Streaming Responses
// Watch your agent think and respond in real-time for enhanced user experience
// Streaming provides immediate feedback and better perceived performance
await foreach (var update in agent.RunStreamingAsync("Plan me a day trip"))
{
    Console.Write(update);  // 📝 Display each response chunk as it arrives
}
# Out:
# I have planned a day trip to Sydney, Australia! Here's a suggested itinerary to make the most of your day:
#
# ### Morning
# **8:00 AM - Breakfast at The Grounds of Alexandria**
# Start your day with a delightful breakfast at this popular venue known for its beautiful gardens and farm-to-table food.
#
# **9:30 AM - Visit the Sydney Opera House**
# Take a stroll to the iconic Sydney Opera House. Consider taking a guided tour to learn about the architecture and history of this remarkable structure.
#
# ### Midday
# **11:00 AM - Explore the Royal Botanic Garden**
# Walk over to the Royal Botanic Garden and enjoy the stunning views of the harbor. It’s a great place for a leisurely walk or even a picnic.
#
# **12:30 PM - Lunch at Circular Quay**
# Head to Circular Quay and have lunch at one of the many restaurants overlooking the harbor. Try some local seafood for an authentic experience.
#
# ### Afternoon
# **2:00 PM - Take a Ferry to Manly**
# Catch a ferry from Circular Quay to Manly Beach. Enjoy the beautiful views of the Sydney skyline from the water.
#
# **3:00 PM - Relax at Manly Beach**
# Spend some time relaxing at the beach, swimming, or walking along the promenade.
#
# ### Evening
# **5:30 PM - Return to Circular Quay**
# Head back to Circular Quay via ferry.
#
# **6:30 PM - Dinner at Darling Harbour**
# End your day with dinner at one of the waterfront restaurants in Darling Harbour. Enjoy the lively atmosphere and possibly catch some live entertainment.
#
# **8:00 PM - Evening Walk**
# After dinner, take a leisurely stroll around Darling Harbour or the Sydney Harbour Bridge for stunning night views.
#
# ### Tips
# - Make sure to check the ferry schedules for timing.
# - Wear comfortable shoes, as there will be a lot of walking.
# - Don't forget sunscreen and a hat for the beach!
#
# Enjoy your day trip to Sydney!
