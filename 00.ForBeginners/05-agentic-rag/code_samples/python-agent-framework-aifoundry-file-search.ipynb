# %%
! pip install agent-framework-azure-ai -U
# Out:
# Collecting agent-framework-azure-ai
#   Downloading agent_framework_azure_ai-1.0.0b251001-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: agent-framework-core in /opt/conda/lib/python3.12/site-packages (from agent-framework-azure-ai) (1.0.0b251001)
# Collecting azure-ai-projects>=1.0.0b11 (from agent-framework-azure-ai)
#   Downloading azure_ai_projects-1.1.0b4-py3-none-any.whl.metadata (24 kB)
# Collecting azure-ai-agents==1.2.0b5 (from agent-framework-azure-ai)
#   Downloading azure_ai_agents-1.2.0b5-py3-none-any.whl.metadata (74 kB)
# Collecting aiohttp~=3.8 (from agent-framework-azure-ai)
#   Downloading aiohttp-3.12.15-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: isodate>=0.6.1 in /opt/conda/lib/python3.12/site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (1.35.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (4.15.0)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp~=3.8->agent-framework-azure-ai)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp~=3.8->agent-framework-azure-ai)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp~=3.8->agent-framework-azure-ai)
#   Downloading frozenlist-1.7.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp~=3.8->agent-framework-azure-ai)
#   Downloading multidict-6.6.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp~=3.8->agent-framework-azure-ai)
#   Downloading propcache-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp~=3.8->agent-framework-azure-ai)
#   Downloading yarl-1.20.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp~=3.8->agent-framework-azure-ai) (3.10)
# Collecting azure-storage-blob>=12.15.0 (from azure-ai-projects>=1.0.0b11->agent-framework-azure-ai)
#   Downloading azure_storage_blob-12.26.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: requests>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (2.32.4)
# Requirement already satisfied: six>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (1.17.0)
# Requirement already satisfied: cryptography>=2.1.4 in /opt/conda/lib/python3.12/site-packages (from azure-storage-blob>=12.15.0->azure-ai-projects>=1.0.0b11->agent-framework-azure-ai) (46.0.2)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects>=1.0.0b11->agent-framework-azure-ai) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects>=1.0.0b11->agent-framework-azure-ai) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (2025.8.3)
# Requirement already satisfied: openai>=1.99.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework-azure-ai) (2.0.1)
# Requirement already satisfied: pydantic<3,>=2 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework-azure-ai) (2.11.9)
# Requirement already satisfied: pydantic-settings<3,>=2 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework-azure-ai) (2.11.0)
# Requirement already satisfied: opentelemetry-api>=1.24 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework-azure-ai) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.24 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework-azure-ai) (1.37.0)
# Requirement already satisfied: mcp>=1.13 in /opt/conda/lib/python3.12/site-packages (from mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (1.15.0)
# Requirement already satisfied: azure-monitor-opentelemetry>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework-azure-ai) (1.8.1)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter>=1.0.0b41 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework-azure-ai) (1.0.0b42)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.36.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework-azure-ai) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework-azure-ai) (0.4.13)
# Requirement already satisfied: aiofiles>=24.1.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework-azure-ai) (24.1.0)
# Requirement already satisfied: azure-identity<2,>=1 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core->agent-framework-azure-ai) (1.25.0)
# Requirement already satisfied: msal>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core->agent-framework-azure-ai) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core->agent-framework-azure-ai) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core->agent-framework-azure-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core->agent-framework-azure-ai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core->agent-framework-azure-ai) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.12/site-packages (from pydantic-settings<3,>=2->agent-framework-core->agent-framework-azure-ai) (1.1.1)
# Requirement already satisfied: azure-core-tracing-opentelemetry~=1.0.0b11 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (1.0.0b12)
# Requirement already satisfied: opentelemetry-instrumentation-django~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-flask~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-requests~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.58b0)
# Requirement already satisfied: opentelemetry-resource-detector-azure~=0.1.5 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.1.5)
# Requirement already satisfied: fixedint==0.1.6 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework-azure-ai) (0.1.6)
# Requirement already satisfied: msrest>=0.6.10 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework-azure-ai) (0.7.1)
# Requirement already satisfied: psutil<8,>=5.9 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework-azure-ai) (7.1.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api>=1.24->agent-framework-core->agent-framework-azure-ai) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.24->agent-framework-core->agent-framework-azure-ai) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-wsgi==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.58b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.58b0)
# Requirement already satisfied: opentelemetry-util-http==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.58b0)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (25.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (1.17.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.58b0)
# Requirement already satisfied: asgiref~=3.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.58b0->opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (3.9.2)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-psycopg2~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework-azure-ai) (0.58b0)
# Requirement already satisfied: anyio>=4.5 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.4.1)
# Requirement already satisfied: httpx>=0.27.1 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (4.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.48.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.37.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.27.1)
# Requirement already satisfied: websockets>=15.0.1 in /opt/conda/lib/python3.12/site-packages (from mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (15.0.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity<2,>=1->agent-framework-core->agent-framework-azure-ai) (2.10.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /opt/conda/lib/python3.12/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework-azure-ai) (2.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core->agent-framework-azure-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core->agent-framework-azure-ai) (0.11.0)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core->agent-framework-azure-ai) (4.67.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework-azure-ai) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework-azure-ai) (1.75.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework-azure-ai) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework-azure-ai) (1.37.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-proto==1.37.0->opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework-azure-ai) (6.32.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework-azure-ai) (3.3.1)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (8.3.0)
# Downloading agent_framework_azure_ai-1.0.0b251001-py3-none-any.whl (12 kB)
# Downloading azure_ai_agents-1.2.0b5-py3-none-any.whl (217 kB)
# Downloading aiohttp-3.12.15-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 21.6 MB/s eta 0:00:00
# Downloading multidict-6.6.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
# Downloading yarl-1.20.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (355 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading azure_ai_projects-1.1.0b4-py3-none-any.whl (126 kB)
# Downloading azure_storage_blob-12.26.0-py3-none-any.whl (412 kB)
# Downloading frozenlist-1.7.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
# Downloading propcache-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (224 kB)
# Installing collected packages: propcache, multidict, frozenlist, aiohappyeyeballs, yarl, aiosignal, azure-storage-blob, azure-ai-agents, aiohttp, azure-ai-projects, agent-framework-azure-ai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [agent-framework-azure-ai]i-projects]]
# Successfully installed agent-framework-azure-ai-1.0.0b251001 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 azure-ai-agents-1.2.0b5 azure-ai-projects-1.1.0b4 azure-storage-blob-12.26.0 frozenlist-1.7.0 multidict-6.6.4 propcache-0.3.2 yarl-1.20.1

# %%
import os

from azure.identity.aio import AzureCliCredential
from dotenv import load_dotenv

from agent_framework import AgentRunResponse,ChatAgent,HostedFileSearchTool,HostedVectorStoreContent
from agent_framework.azure import AzureAIAgentClient

# %%
load_dotenv()
# Out:
# True

# %%
async def create_vector_store(client: AzureAIAgentClient) -> tuple[str, HostedVectorStoreContent]:
    """Create a vector store with sample documents."""
    file_path = './document.md'
    file = await client.project_client.agents.files.upload_and_poll(file_path=file_path, purpose="assistants")
    print(f"Uploaded file, file ID: {file.id}")


    vector_store = await client.project_client.agents.vector_stores.create_and_poll(file_ids=[file.id], name="graph_knowledge_base")

    print(f"Created vector store, ID: {vector_store.id}")


    return file.id, HostedVectorStoreContent(vector_store_id=vector_store.id)

# %%
async with (
        AzureCliCredential() as credential,
        AzureAIAgentClient(async_credential=credential) as chat_client,
    ):
        file_id, vector_store = await create_vector_store(chat_client)

        file_search = HostedFileSearchTool(inputs=vector_store)
        
        agent = chat_client.create_agent(
            name="PythonRAGDemo",
            instructions="""
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            tools=[file_search],  # Tools available to the agent
            tool_choice = "auto",  # Let the agent decide when to use tools
        )
                

        print("Agent created. You can now ask questions about the uploaded document.")

        query = "Can you explain Contoso's travel insurance coverage?"
        async for chunk in agent.run_stream(query, tool_resources={"file_search": {"vector_store_ids": [vector_store.vector_store_id]}}):
                
            if chunk.text:
                print(chunk.text, end="", flush=True)
# Out:
# Uploaded file, file ID: assistant-DKViJ286k43a7E9qjYGvHK
# Created vector store, ID: vs_HUp5LGRQwkcPbt5KK7UYNmMi
# Agent created. You can now ask questions about the uploaded document.
# Contoso's travel insurance provides coverage for medical emergencies, trip cancellations, and lost baggage【4:0†document.md】.
