# %% [markdown]
# # 🐍 AI Travel Agent with Microsoft Agent Framework (Python)
#
# ## 📋 Scenario Overview
#
# This notebook demonstrates how to build an intelligent travel planning agent using the Microsoft Agent Framework for Python. The agent leverages GitHub Models to automatically generate personalized day-trip itineraries for random destinations worldwide.
#
# **Key Features:**
# - 🎲 **Smart Destination Selection**: Custom tool function for random destination picking
# - 🗺️ **Detailed Itinerary Generation**: AI-powered travel planning with local recommendations
# - 🔄 **Async Processing**: Uses asyncio for efficient API communication
# - 🛠️ **Tool Integration**: Demonstrates function calling capabilities in AI agents
#
# ## 🏗️ Technical Implementation
#
# ### Core Components
# - **Agent Framework**: Python implementation of Microsoft's agent orchestration system
# - **GitHub Models API**: Access to state-of-the-art language models via GitHub's inference service
# - **OpenAI Compatibility**: Uses OpenAI client patterns with GitHub Models backend
# - **Environment Management**: Secure credential handling with python-dotenv
#
# ### Architecture Flow
# ```python
# User Request → ChatAgent → GitHub Models API ↔ get_random_destination()
#                      ↓
#               Travel Itinerary Response
# ```
#
# ### Key Classes & Methods
# - `ChatAgent`: Main conversational agent orchestrator
# - `OpenAIChatClient`: GitHub Models API client wrapper
# - `get_random_destination()`: Custom tool function for destination selection
# - Environment variables: Secure API configuration management
#
# ## ⚙️ Prerequisites & Setup
#
# **Required Dependencies:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Environment Configuration (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **GitHub Models Access:**
# 1. Sign up for GitHub Models access
# 2. Generate a personal access token
# 3. Configure environment variables as shown above
#
# ## 🚀 Usage Instructions
#
# Execute the cells below in sequence to:
# 1. Import required libraries and load environment variables
# 2. Define the random destination generator tool
# 3. Create and configure the AI agent
# 4. Run travel planning requests and view results
#
# Let's build an intelligent travel planning assistant! 🌟

# %%
! pip install agent-framework-core -U
# Out:
# Requirement already satisfied: agent-framework-core in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (1.0.0b251114)
# Requirement already satisfied: typing-extensions in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from agent-framework-core) (2.12.3)
# Requirement already satisfied: pydantic-settings<3,>=2 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from agent-framework-core) (2.10.1)
# Requirement already satisfied: opentelemetry-api>=1.24 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from agent-framework-core) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.24 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from agent-framework-core) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.36.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from agent-framework-core) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from agent-framework-core) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from agent-framework-core) (2.8.1)
# Requirement already satisfied: azure-identity<2,>=1 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from agent-framework-core) (1.25.1)
# Requirement already satisfied: mcp>=1.13 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from mcp[ws]>=1.13->agent-framework-core) (1.21.2)
# Requirement already satisfied: packaging>=24.1 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from agent-framework-core) (25.0)
# Requirement already satisfied: azure-core>=1.31.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.36.0)
# Requirement already satisfied: cryptography>=2.5 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from pydantic<3,>=2->agent-framework-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from pydantic<3,>=2->agent-framework-core) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from pydantic<3,>=2->agent-framework-core) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from pydantic-settings<3,>=2->agent-framework-core) (1.1.0)
# Requirement already satisfied: requests>=2.21.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: pycparser in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.21)
# Requirement already satisfied: anyio>=4.5 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (4.25.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.50.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.38.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (3.3)
# Requirement already satisfied: sniffio>=1.1 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (1.3.0)
# Requirement already satisfied: certifi in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.28.0)
# Requirement already satisfied: websockets>=15.0.1 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from mcp[ws]>=1.13->agent-framework-core) (15.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from openai>=1.99.0->agent-framework-core) (0.12.0)
# Requirement already satisfied: tqdm>4 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from openai>=1.99.0->agent-framework-core) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from opentelemetry-api>=1.24->agent-framework-core) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.24->agent-framework-core) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.72.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.76.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.38.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from opentelemetry-proto==1.38.0->opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (6.33.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from opentelemetry-sdk>=1.24->agent-framework-core) (0.59b0)
# Requirement already satisfied: click>=7.0 in /Users/jiancs/opt/anaconda3/lib/python3.10/site-packages (from uvicorn>=0.31.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (8.2.1)

# %%
# 📦 Import Required Libraries
# Standard library imports for system operations and random number generation
import os
from random import randint

# Third-party library for loading environment variables from .env file
from dotenv import load_dotenv

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatAgent: The main agent class for conversational AI
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs (including GitHub Models)
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# This loads configuration from a .env file in the project root
# Required variables: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID
load_dotenv()
# Out:
# True

# %%
# 🎲 Tool Function: Random Destination Generator
# This function will be available to the agent as a tool
# The agent can call this function to get random vacation destinations
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    Returns:
        str: A randomly selected destination from our predefined list
    """
    # List of popular vacation destinations around the world
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a random destination from the list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client for GitHub Models
# This client connects to GitHub Models API (OpenAI-compatible endpoint)
# Environment variables required:
# - GITHUB_ENDPOINT: API endpoint URL (usually https://models.inference.ai.azure.com)
# - GITHUB_TOKEN: Your GitHub personal access token
# - GITHUB_MODEL_ID: Model to use (e.g., gpt-4o-mini, gpt-4o)
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),
    api_key=os.environ.get("GITHUB_TOKEN"), 
    model_id=os.environ.get("GITHUB_MODEL_ID")
)

# %%
# 🤖 Create the Travel Planning Agent
# This creates a conversational AI agent with specific capabilities:
# - chat_client: The AI model client for generating responses
# - instructions: System prompt that defines the agent's personality and role
# - tools: List of functions the agent can call to perform actions
agent = ChatAgent(
    chat_client=openai_chat_client,
    instructions="You are a helpful AI Agent that can help plan vacations for customers at Beijing.",
    tools=[get_random_destination]  # Our random destination tool function
)

# %%
# 🚀 Run the Agent
# Send a message to the agent and get a response
# The agent will use its tools (get_random_destination) if needed
response = await agent.run("Plan me a day trip")

# %%
# 📋 View Raw Response Object
# This shows the complete response structure including metadata
# Useful for debugging and understanding the response format
response

# %%
# 📖 Extract and Display the Travel Plan
# Get the last message from the conversation (agent's response)s
last_message = response.messages[-1]
# Extract the text content from the message
text_content = last_message.contents[0].text
# Display the formatted travel plan
print("🏖️ Travel plan:")
print(text_content)
# Out:
# 🏖️ Travel plan:
# A randomly selected destination for your day trip is Cairo, Egypt. Here's how you could spend a day exploring this vibrant city:
#
# 1. **Morning: Giza Plateau**
#    - Start your day early with a visit to the Giza Plateau to see the Great Pyramids and the Sphinx. You can hire a guide to learn about the fascinating history of these ancient wonders.
#
# 2. **Mid-Morning: Egyptian Museum**
#    - Head to the Egyptian Museum to marvel at the extensive collection of artifacts from ancient Egypt, including the treasures of Tutankhamun.
#
# 3. **Lunch: Traditional Egyptian Cuisine**
#    - Enjoy lunch at a local restaurant and savor traditional Egyptian dishes like Koshari or Falafel.
#
# 4. **Afternoon: Khan El Khalili Bazaar**
#    - Spend your afternoon exploring the bustling Khan El Khalili Bazaar. It's a great place to shop for souvenirs and experience the local culture and craftsmanship.
#
# 5. **Coffee Break: Al Fishawi Cafe**
#    - Take a break at Al Fishawi, Cairo's oldest café, and enjoy a traditional mint tea or Arabic coffee while soaking in the lively atmosphere.
#
# 6. **Evening: Dinner Cruise on the Nile**
#    - End your day with a relaxing dinner cruise on the Nile River. Enjoy a meal while watching traditional Egyptian music and dance performances.
#
# 7. **Alternatives:**
#    - If you’re interested in Islamic architecture, consider a visit to the Citadel of Saladin to see the beautiful Alabaster Mosque.
#    - For a more relaxed option, spend your evening at one of Cairo's rooftop bars for a stunning view of the cityscape at night.
#
# Remember to check the opening hours and availability of tours in advance, and consider hiring a local guide to enhance your experience in Cairo. Enjoy your trip!
