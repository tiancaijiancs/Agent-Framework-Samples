# %%
# 📦 Import Required Libraries
# Standard library imports for system operations and random number generation
import os
from random import randint

# Third-party library for loading environment variables from .env file
from dotenv import load_dotenv

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatAgent: The main agent class for conversational AI
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs (including GitHub Models)
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# This loads configuration from a .env file in the project root
# Required variables: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID
load_dotenv()
# Out:
# True

# %%
# 🎲 Tool Function: Random Destination Generator
# This function will be available to the agent as a tool
# The agent can call this function to get random vacation destinations
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    Returns:
        str: A randomly selected destination from our predefined list
    """
    # List of popular vacation destinations around the world
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a random destination from the list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client for GitHub Models
# This client connects to GitHub Models API (OpenAI-compatible endpoint)
# Environment variables required:
# - GITHUB_ENDPOINT: API endpoint URL (usually https://models.inference.ai.azure.com)
# - GITHUB_TOKEN: Your GitHub personal access token
# - GITHUB_MODEL_ID: Model to use (e.g., gpt-4o-mini, gpt-4o)
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),
    api_key=os.environ.get("GITHUB_TOKEN"), 
    ai_model_id=os.environ.get("GITHUB_MODEL_ID")
)

# %%
# 🤖 Create the Travel Planning Agent
# This creates a conversational AI agent with specific capabilities:
# - chat_client: The AI model client for generating responses
# - instructions: System prompt that defines the agent's personality and role
# - tools: List of functions the agent can call to perform actions
agent = ChatAgent(
    chat_client=openai_chat_client,
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",
    tools=[get_random_destination]  # Our random destination tool function
)

# %%
# 🚀 Run the Agent
# Send a message to the agent and get a response
# The agent will use its tools (get_random_destination) if needed
response = await agent.run("Plan me a day trip")

# %%
# 📋 View Raw Response Object
# This shows the complete response structure including metadata
# Useful for debugging and understanding the response format
response
# Out:
# AgentRunResponse(messages=[ChatMessage(role=Role(value='assistant'), contents=[FunctionCallContent(annotations=None, additional_properties=None, type='function_call', call_id='call_ZLxNWQkezpCeOe5Zy993mRqJ', name='get_random_destination', arguments='{}', exception=None)], author_name='UnnamedAgent', message_id=None, additional_properties=None, raw_representation=None), ChatMessage(role=Role(value='tool'), contents=[FunctionResultContent(annotations=None, additional_properties=None, type='function_result', call_id='call_ZLxNWQkezpCeOe5Zy993mRqJ', result='Rio de Janeiro, Brazil', exception=None)], author_name='UnnamedAgent', message_id=None, additional_properties=None, raw_representation=None), ChatMessage(role=Role(value='assistant'), contents=[TextContent(annotations=None, additional_properties=None, text="Let's plan a day trip to Rio de Janeiro, Brazil! Here's a suggested itinerary for your adventure:\n\n### Morning:\n- **Breakfast at a Local Café**: Start your day with a traditional Brazilian breakfast. Try pão de queijo (cheese bread) and a strong cup of Brazilian coffee.\n- **Visit Christ the Redeemer**: Head to the iconic Christ the Redeemer statue. You can take a train or van to the top of Corcovado Mountain for stunning views of the city.\n\n### Afternoon:\n- **Lunch at a Churrascaria**: Enjoy a hearty Brazilian barbecue lunch at a local churrascaria, where you can savor various types of grilled meats.\n- **Explore Santa Teresa Neighborhood**: Walk around Santa Teresa, a charming neighborhood known for its narrow streets, artist studios, and colonial-style houses. Don't forget to snap pictures of the colorful Selarón Steps.\n\n### Evening:\n- **Relax at Copacabana Beach**: Spend some time at the famous Copacabana Beach. You can sunbathe, swim, or simply enjoy a caipirinha from a beachside vendor.\n- **Dinner at a Seafood Restaurant**: Treat yourself to a delicious seafood dinner at one of the many restaurants along the beach with ocean views.\n- **Sunset at Sugarloaf Mountain**: End your day by taking the cable car to Sugarloaf Mountain for a breathtaking sunset over the city.\n\n### Tips:\n- Keep your belongings secure while exploring.\n- Consider using rideshare apps for convenient transportation between destinations.\n- Stay hydrated and wear sunscreen, especially at the beach and during outdoor activities.\n\nEnjoy your day trip in Rio de Janeiro!", type='text')], author_name='UnnamedAgent', message_id=None, additional_properties=None, raw_representation=None)], response_id='chatcmpl-CJv1HJdQIHA1uxuEq8s7sxCfsFzZN', created_at='2025-09-26T13:10:51.000000Z', usage_details=UsageDetails(input_token_count=98, output_token_count=336, total_token_count=434), value=None, raw_representation=ChatResponse(messages=[ChatMessage(role=Role(value='assistant'), contents=[FunctionCallContent(annotations=None, additional_properties=None, type='function_call', call_id='call_ZLxNWQkezpCeOe5Zy993mRqJ', name='get_random_destination', arguments='{}', exception=None)], author_name='UnnamedAgent', message_id=None, additional_properties=None, raw_representation=None), ChatMessage(role=Role(value='tool'), contents=[FunctionResultContent(annotations=None, additional_properties=None, type='function_result', call_id='call_ZLxNWQkezpCeOe5Zy993mRqJ', result='Rio de Janeiro, Brazil', exception=None)], author_name='UnnamedAgent', message_id=None, additional_properties=None, raw_representation=None), ChatMessage(role=Role(value='assistant'), contents=[TextContent(annotations=None, additional_properties=None, text="Let's plan a day trip to Rio de Janeiro, Brazil! Here's a suggested itinerary for your adventure:\n\n### Morning:\n- **Breakfast at a Local Café**: Start your day with a traditional Brazilian breakfast. Try pão de queijo (cheese bread) and a strong cup of Brazilian coffee.\n- **Visit Christ the Redeemer**: Head to the iconic Christ the Redeemer statue. You can take a train or van to the top of Corcovado Mountain for stunning views of the ci ...

# %%
# 📖 Extract and Display the Travel Plan
# Get the last message from the conversation (agent's response)
last_message = response.messages[-1]
# Extract the text content from the message
text_content = last_message.contents[0].text
# Display the formatted travel plan
print("🏖️ Travel plan:")
print(text_content)
# Out:
# 🏖️ Travel plan:
# Let's plan a day trip to Rio de Janeiro, Brazil! Here's a suggested itinerary for your adventure:
#
# ### Morning:
# - **Breakfast at a Local Café**: Start your day with a traditional Brazilian breakfast. Try pão de queijo (cheese bread) and a strong cup of Brazilian coffee.
# - **Visit Christ the Redeemer**: Head to the iconic Christ the Redeemer statue. You can take a train or van to the top of Corcovado Mountain for stunning views of the city.
#
# ### Afternoon:
# - **Lunch at a Churrascaria**: Enjoy a hearty Brazilian barbecue lunch at a local churrascaria, where you can savor various types of grilled meats.
# - **Explore Santa Teresa Neighborhood**: Walk around Santa Teresa, a charming neighborhood known for its narrow streets, artist studios, and colonial-style houses. Don't forget to snap pictures of the colorful Selarón Steps.
#
# ### Evening:
# - **Relax at Copacabana Beach**: Spend some time at the famous Copacabana Beach. You can sunbathe, swim, or simply enjoy a caipirinha from a beachside vendor.
# - **Dinner at a Seafood Restaurant**: Treat yourself to a delicious seafood dinner at one of the many restaurants along the beach with ocean views.
# - **Sunset at Sugarloaf Mountain**: End your day by taking the cable car to Sugarloaf Mountain for a breathtaking sunset over the city.
#
# ### Tips:
# - Keep your belongings secure while exploring.
# - Consider using rideshare apps for convenient transportation between destinations.
# - Stay hydrated and wear sunscreen, especially at the beach and during outdoor activities.
#
# Enjoy your day trip in Rio de Janeiro!
