# %% [markdown]
# # 🛠️ Advanced Tool Use with GitHub Models (Python)
#
# ## 📋 Learning Objectives
#
# This notebook demonstrates advanced tool integration patterns using the Microsoft Agent Framework with GitHub Models. You'll learn how to create, manage, and orchestrate multiple tools to build sophisticated agent capabilities.
#
# **What You'll Master:**
# - 🔧 **Multi-Tool Architecture**: Building agents with multiple specialized tools
# - 🎯 **Tool Selection Logic**: How agents choose the right tool for each task
# - 📊 **Data Processing Tools**: Creating tools that handle different data types
# - 🔗 **Tool Composition**: Combining tools for complex workflows
#
# ## 🎯 Key Tool Patterns
#
# ### Tool Design Principles
# - **Single Responsibility**: Each tool has a clear, focused purpose
# - **Type Safety**: Strong typing for reliable tool execution
# - **Error Handling**: Graceful failure and recovery patterns
# - **Composability**: Tools that work well together
#
# ### Advanced Tool Features
# - **Context Awareness**: Tools that understand conversation context
# - **Data Validation**: Input sanitization and output validation
# - **Performance Optimization**: efficient tool execution patterns
# - **Extensibility**: Easy addition of new tool capabilities
#
# ## 🔧 Technical Architecture
#
# ### Core Components
# - **Microsoft Agent Framework**: Python implementation with advanced tool support
# - **GitHub Models Integration**: High-performance language model access
# - **Tool Registry System**: Organized management of agent capabilities
# - **Error Recovery Patterns**: Robust handling of tool execution failures
#
# ### Tool Integration Flow
# ```python
# User Request → Agent Analysis → Tool Selection → Tool Execution → Response Synthesis
# ```
#
# ## 🛠️ Tool Categories Demonstrated
#
# ### 1. **Data Generation Tools**
# - Random destination generator
# - Weather information provider
# - Travel cost calculator
# - Activity recommendation engine
#
# ### 2. **Processing Tools**
# - Text formatting and validation
# - Data transformation utilities
# - Content analysis functions
# - Response enhancement tools
#
# ### 3. **Integration Tools**
# - External API connectors
# - File system operations
# - Database query interfaces
# - Web scraping utilities
#
# ## ⚙️ Prerequisites & Setup
#
#
# **Required Dependencies:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Environment Configuration (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Optional APIs:**
# - Weather service API key (for weather tools)
# - Currency conversion API access
# - Travel information service credentials
#
# ## 🎨 Design Patterns
#
# ### Tool Factory Pattern
# - Centralized tool creation and configuration
# - Consistent tool interface design
# - Easy tool registration and discovery
#
# ### Command Pattern
# - Encapsulated tool execution logic
# - Undo/redo functionality for complex operations
# - Audit logging for tool usage
#
# ### Observer Pattern
# - Tool execution monitoring
# - Performance metrics collection
# - Error reporting and alerting
#
# ## 🚀 Best Practices
#
# - **Tool Documentation**: Clear descriptions for agent understanding
# - **Input Validation**: Robust parameter checking and sanitization
# - **Output Formatting**: Consistent, parseable tool responses
# - **Error Messages**: Helpful error information for debugging
# - **Performance**: Optimized tool execution for responsiveness
#
# Ready to build agents with powerful tool capabilities? Let's create something amazing! ⚡

# %%
! pip install agent-framework-core -U
# Out:
# Requirement already satisfied: agent-framework-core in /opt/conda/lib/python3.12/site-packages (1.0.0b251001)
# Requirement already satisfied: openai>=1.99.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (2.0.1)
# Requirement already satisfied: pydantic<3,>=2 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (2.11.9)
# Requirement already satisfied: pydantic-settings<3,>=2 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (2.11.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: opentelemetry-api>=1.24 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.24 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (1.37.0)
# Requirement already satisfied: mcp>=1.13 in /opt/conda/lib/python3.12/site-packages (from mcp[ws]>=1.13->agent-framework-core) (1.15.0)
# Requirement already satisfied: azure-monitor-opentelemetry>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (1.8.1)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter>=1.0.0b41 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (1.0.0b42)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.36.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (0.4.13)
# Requirement already satisfied: aiofiles>=24.1.0 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (24.1.0)
# Requirement already satisfied: azure-identity<2,>=1 in /opt/conda/lib/python3.12/site-packages (from agent-framework-core) (1.25.0)
# Requirement already satisfied: azure-core>=1.31.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.35.1)
# Requirement already satisfied: cryptography>=2.5 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.2)
# Requirement already satisfied: msal>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.12/site-packages (from pydantic-settings<3,>=2->agent-framework-core) (1.1.1)
# Requirement already satisfied: requests>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.4)
# Requirement already satisfied: six>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (1.17.0)
# Requirement already satisfied: azure-core-tracing-opentelemetry~=1.0.0b11 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (1.0.0b12)
# Requirement already satisfied: opentelemetry-instrumentation-django~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-flask~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-requests~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-resource-detector-azure~=0.1.5 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.1.5)
# Requirement already satisfied: fixedint==0.1.6 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (0.1.6)
# Requirement already satisfied: msrest>=0.6.10 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (0.7.1)
# Requirement already satisfied: psutil<8,>=5.9 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (7.1.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api>=1.24->agent-framework-core) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.24->agent-framework-core) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-wsgi==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: opentelemetry-util-http==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (25.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (1.17.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: asgiref~=3.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.58b0->opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (3.9.2)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-psycopg2~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.58b0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.22)
# Requirement already satisfied: anyio>=4.5 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.4.1)
# Requirement already satisfied: httpx>=0.27.1 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (4.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.48.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/conda/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.37.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.12/site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (1.3.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.27.1)
# Requirement already satisfied: websockets>=15.0.1 in /opt/conda/lib/python3.12/site-packages (from mcp[ws]>=1.13->agent-framework-core) (15.0.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity<2,>=1->agent-framework-core) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.5.0)
# Requirement already satisfied: isodate>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (0.7.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /opt/conda/lib/python3.12/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (2.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core) (0.11.0)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core) (4.67.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.75.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.37.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-proto==1.37.0->opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (6.32.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (3.3.1)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (8.3.0)

# %%
# � Import core dependencies for Agent Framework and tool integration
# This sets up the essential libraries for building intelligent agents with tool capabilities

import asyncio
import os
import json

from dotenv import load_dotenv  # For loading environment variables securely
from random import randint

# These are the core components for building tool-enabled agents
from agent_framework import ChatAgent           # Main agent class
from agent_framework.openai import OpenAIChatClient  # OpenAI-compatible client

# %%
load_dotenv()
# Out:
# True

# %%
# 🔑 Environment variables verification
# Ensure all required GitHub Models credentials are properly configured
print("GITHUB_ENDPOINT:", os.environ.get("GITHUB_ENDPOINT"))
print("GITHUB_TOKEN:", "***" if os.environ.get("GITHUB_TOKEN") else "Not set")
print("GITHUB_MODEL_ID:", os.environ.get("GITHUB_MODEL_ID"))
# Out:
# GITHUB_ENDPOINT: https://models.github.ai/inference
# GITHUB_TOKEN: ***
# GITHUB_MODEL_ID: gpt-4o-mini

# %%
# 🧪 Test GitHub Models connectivity
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
# 🛠️ Define travel planning tools for agent integration
# These functions provide specific capabilities that the agent can invoke dynamically

def get_random_destination() -> str:
    """
    🎲 Random destination generator tool
    Returns a randomly selected travel destination from curated list
    Useful when customers need inspiration for their next vacation
    """
    destinations = [
        "Paris, France",
        "Tokyo, Japan", 
        "New York City, USA",
        "London, England",
        "Rome, Italy",
        "Sydney, Australia",
        "Dubai, UAE",
        "Barcelona, Spain",
        "Bangkok, Thailand",
        "Amsterdam, Netherlands",
        "Istanbul, Turkey",
        "Prague, Czech Republic",
        "Santorini, Greece",
        "Reykjavik, Iceland",
        "Marrakech, Morocco",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # 🎯 Return random selection from the curated destination list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Initialize GitHub Models chat client for agent communication
# Creates the primary interface between the agent and the language model
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
# 🤖 Configure travel agent identity and behavioral instructions
# Define the agent's personality, capabilities, and operational guidelines

AGENT_NAME = "TravelAgent"

AGENT_INSTRUCTIONS = """You are a helpful AI Agent that can help plan vacations for customers at random destinations
"""

# %%
agent = ChatAgent(
        name = AGENT_NAME,
        chat_client=openai_chat_client,
        instructions=AGENT_INSTRUCTIONS,
        tools=[get_random_destination]
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# How about a delightful day trip to Paris, France? Here's a suggested itinerary for your day:
#
# ### Morning:
# - **Breakfast at a Café:** Start your day with a quintessential French breakfast at a local café. Enjoy a croissant and a cup of café au lait.
# - **Visit the Eiffel Tower:** Take a stroll to the iconic Eiffel Tower. You can either go up for stunning views of the city or enjoy the view from the gardens below.
#
# ### Mid-Morning:
# - **Explore the Louvre Museum:** Head over to the Louvre to see some of the world's most famous artworks, including the Mona Lisa and the Venus de Milo. Be sure to check online for ticket availability to avoid long lines.
#
# ### Lunch:
# - **Lunch in Le Marais:** Explore the trendy Le Marais district and enjoy lunch at one of the many bistros or restaurants offering delicious French cuisine.
#
# ### Afternoon:
# - **Walk along the Seine River:** After lunch, take a leisurely walk along the Seine. You can also stop by the charming Île de la Cité and visit the Notre-Dame Cathedral (check for any restrictions due to ongoing restoration).
# - **Visit Montmartre:** Head to Montmartre to explore its artist vibe, visit the Sacré-Cœur Basilica, and enjoy the panoramic view of Paris.
#
# ### Evening:
# - **Dinner in a Traditional Bistro:** Conclude your day with dinner in a traditional Parisian bistro. Savor classic French dishes like Coq au Vin or Bouillabaisse.
# - **Evening Seine River Cruise:** If time permits, consider taking a romantic Seine River cruise to see the city lights sparkling at night.
#
# ### Tips:
# - Wear comfortable shoes for walking.
# - Stay hydrated and take breaks as needed.
# - Consider getting a Paris Pass for discounted entry to attractions and public transportation.
#
# Enjoy your day in Paris!
