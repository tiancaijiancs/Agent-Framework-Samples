# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.0</span></li></ul></div></div>

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.OpenAI\bin\Debug\net9.0\Microsoft.Agents.AI.OpenAI.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI\bin\Debug\net9.0\Microsoft.Agents.AI.dll"

# %%
#r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.ComponentModel;
using System.ClientModel;

using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using OpenAI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
[Description("Provides a random vacation destination.")]
static string GetRandomDestination()
{
    var destinations = new List<string>
    {
        "Paris, France",
        "Tokyo, Japan",
        "New York City, USA",
        "Sydney, Australia",
        "Rome, Italy",
        "Barcelona, Spain",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bangkok, Thailand",
        "Vancouver, Canada"
    };

    var random = new Random();
    int index = random.Next(destinations.Count);
    return destinations[index];
}

# %%
var github_endpoint = Environment.GetEnvironmentVariable("GITHUB_ENDPOINT") ?? throw new InvalidOperationException("GITHUB_ENDPOINT is not set.");
var github_model_id = Environment.GetEnvironmentVariable("GITHUB_MODEL_ID") ?? "gpt-4o-mini";
var github_token = Environment.GetEnvironmentVariable("GITHUB_TOKEN") ?? throw new InvalidOperationException("GITHUB_TOKEN is not set.");

# %%
var openAIOptions = new OpenAIClientOptions()
{
    Endpoint= new Uri(github_endpoint)
};

# %%
var openAIClient = new OpenAIClient(new ApiKeyCredential(github_token), openAIOptions);

# %%
AIAgent agent = new OpenAIClient(new ApiKeyCredential(github_token), openAIOptions).GetChatClient(github_model_id).CreateAIAgent(
    instructions:"You are a helpful AI Agent that can help plan vacations for customers at random destinations", tools: [AIFunctionFactory.Create((Func<string>)GetRandomDestination)]);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Plan me a day trip",thread));
# Out:
# Here’s a plan for a day trip to Rio de Janeiro, Brazil:
#
# ### Morning:
# 1. **Breakfast at a Local Café**:
#    - Start your day with a traditional Brazilian breakfast at a local café. Try some "pão de queijo" (cheese bread) and fresh tropical fruits.
#
# 2. **Visit Christ the Redeemer**:
#    - Take a morning trip to one of the New Seven Wonders of the World. You can either hike up to the statue or take a train ride through the Tijuca Forest. Enjoy the breathtaking views of the city from the top.
#
# ### Afternoon:
# 3. **Lunch at Santa Teresa**:
#    - Head to the charming neighborhood of Santa Teresa, known for its winding streets and artistic vibe. Have lunch at a restaurant serving traditional Brazilian cuisine.
#
# 4. **Explore the Selarón Steps**:
#    - After lunch, visit the Escadaria Selarón, a colorful staircase created by artist Jorge Selarón. This vibrant mosaic is a perfect spot for photos and a brief walk.
#
# 5. **Beach Time at Copacabana**:
#    - Spend the afternoon soaking up the sun at Copacabana Beach. You can relax, swim, or enjoy some beach volleyball.
#
# ### Evening:
# 6. **Dinner in Ipanema**:
#    - As the sun sets, head over to Ipanema and dine at a beachside restaurant. Enjoy fresh seafood and a drink while taking in the stunning views.
#
# 7. **Night Walk along the Beach**:
#    - After dinner, take a leisurely stroll along the beach. The night atmosphere with the sound of the waves is magical.
#
# ### Optional:
# - If you have more energy, check out a samba club or live music venue to experience the vibrant nightlife of Rio.
#
# ### Tips:
# - Make sure to stay hydrated and wear sunscreen.
# - Be mindful of your belongings while exploring busy areas.
#
# Enjoy your day trip in Rio de Janeiro!

# %%
Console.WriteLine(await agent.RunAsync("I don't like that destination. Plan me another vacation.",thread));
# Out:
# Here's a plan for a day trip to Vancouver, Canada:
#
# ### Morning:
# 1. **Breakfast in Gastown**:
#    - Start your day in the historic Gastown district with breakfast at a cozy café. Try some local specialties, like pancakes with maple syrup.
#
# 2. **Visit Stanley Park**:
#    - After breakfast, head to Stanley Park. Rent a bike to explore the park's scenic seawall and visit the Totem Poles. Enjoy the lush greenery and stunning views of the city skyline.
#
# ### Afternoon:
# 3. **Lunch at Granville Island**:
#    - Make your way to Granville Island for lunch. This vibrant area features a public market where you can grab a bite from various food stalls. Enjoy fresh seafood, artisanal cheeses, or delicious baked goods.
#
# 4. **Explore Granville Island**:
#    - After lunch, wander around Granville Island to check out local shops, galleries, and the artisan market. You can also take a walk along the waterfront for picturesque views.
#
# 5. **Visit the Vancouver Aquarium**:
#    - Head back to Stanley Park and visit the Vancouver Aquarium, home to a variety of marine life and engaging exhibits.
#
# ### Evening:
# 6. **Dinner in Yaletown**:
#    - For dinner, go to Yaletown, known for its trendy restaurants. Enjoy a nice meal, maybe try the local salmon or other pacific northwest dishes.
#
# 7. **Sunset at English Bay Beach**:
#    - After dinner, stroll over to English Bay Beach to catch a beautiful sunset. It's a perfect spot to relax and enjoy the view of the sunset over the ocean.
#
# ### Optional:
# - If you're up for it, consider taking a sunset cruise or a walk along the seawall to finish your day.
#
# ### Tips:
# - Dress in layers, as the weather can change quickly in Vancouver.
# - Public transport is convenient, so consider using buses or SkyTrain to get around.
#
# Enjoy your day trip in Vancouver!
