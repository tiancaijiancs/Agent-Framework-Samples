# %%
# 📚 Exploring Agentic Frameworks - Basic Agent Example
# This example demonstrates core concepts of the Microsoft Agent Framework

# 📦 Import Required Libraries
import os                     # For environment variable access
from random import randint    # For generating random selections

from dotenv import load_dotenv  # For loading .env configuration files

# %%
# 🤖 Import Core Agent Framework Components
# ChatAgent: The main conversational agent class
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Initialize Environment Configuration
# Load environment variables from .env file
# This enables secure storage of API keys and endpoints
load_dotenv()
# Out:
# True

# %%
# 🛠️ Tool Function: Random Destination Generator
# This demonstrates how to create tools that agents can use
# Tools extend the agent's capabilities beyond just conversation
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    This function serves as a tool that the agent can call when it needs
    to suggest a random destination for travel planning.
    
    Returns:
        str: A randomly selected destination from the predefined list
    """
    # Curated list of popular vacation destinations worldwide
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a randomly selected destination
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client
# This demonstrates how to connect to GitHub Models (OpenAI-compatible API)
# The client handles all communication with the AI model
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # API endpoint URL
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    ai_model_id=os.environ.get("GITHUB_MODEL_ID")  # Model identifier (e.g., gpt-4o-mini)
)

# %%
# 🤖 Create the Basic Agent
# This demonstrates the core agent creation pattern in the framework
# Key components: chat client, instructions, and tools
agent = ChatAgent(
    chat_client=openai_chat_client,  # The AI model client for generating responses
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",  # System prompt defining agent behavior
    tools=[get_random_destination]   # List of available tools the agent can use
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# I have selected Tokyo, Japan as your destination for a day trip! Here’s a suggested itinerary for your day in Tokyo:
#
# ### Morning:
# - **Breakfast at Tsukiji Outer Market**: Start your day with a delicious breakfast of fresh sushi or seafood at one of the many stalls and eateries in this famous market.
#
# - **Visit the Senso-ji Temple**: Head to Asakusa to see Tokyo’s oldest temple. Take a stroll down Nakamise Street, where you can find traditional snacks and souvenirs.
#
# ### Afternoon:
# - **Lunch in Akihabara**: Dive into the otaku culture with lunch at a themed café or try some ramen at one of the local restaurants.
#
# - **Explore Akihabara**: After lunch, spend some time browsing electronics shops, anime stores, and game centers in this vibrant district.
#
# ### Evening:
# - **Shibuya Crossing**: Make your way to Shibuya, famous for its bustling pedestrian scramble. Snap a photo with the Hachiko statue nearby.
#
# - **Dinner in Shinjuku**: Head to the lively district of Shinjuku for dinner. You have many options, from izakayas (Japanese pubs) to fine dining.
#
# - **Night View from Tokyo Metropolitan Government Building**: End your day with a stunning panoramic view of the city from the observation deck of the Tokyo Metropolitan Government Building.
#
# ### Tips:
# - Make sure to get a Suica or Pasmo card for easy travel on public transport.
# - Wear comfortable shoes as you will be doing a lot of walking.
#
# Enjoy your day trip to Tokyo!

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",thread= thread)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# Your new destination is Barcelona, Spain! Here’s a suggested itinerary for a day trip in Barcelona:
#
# ### Morning:
# - **Breakfast at a Local Café**: Start your day with a traditional Spanish breakfast of "pan con tomate" (bread with tomato) and a café con leche at a local café.
#
# - **Visit La Sagrada Familia**: Head to Antoni Gaudí's masterpiece, the Sagrada Familia. Make sure to book your tickets in advance to skip the lines!
#
# ### Afternoon:
# - **Lunch at La Boqueria Market**: Enjoy a vibrant lunch at the famous La Boqueria Market. Try some tapas or fresh seafood from one of the stalls.
#
# - **Stroll through the Gothic Quarter**: After lunch, explore the narrow streets of the Gothic Quarter. Don't miss the Barcelona Cathedral and the charming Plaça del Rei.
#
# ### Evening:
# - **Visit Park Güell**: Spend your afternoon at Park Güell, where you can see more of Gaudí's work and enjoy beautiful views of the city.
#
# - **Dinner at a Tapas Bar**: For dinner, find a cozy tapas bar in El Born or Gràcia to sample varied Spanish dishes and local wine.
#
# - **Flamenco Show**: End your day with a traditional Flamenco show, experiencing the passionate dance and music that’s a part of Spanish culture.
#
# ### Tips:
# - Consider using the Barcelona Metro for easy transportation.
# - Wear comfortable shoes as there is a lot to see and walk.
#
# Enjoy your day in the beautiful city of Barcelona!
